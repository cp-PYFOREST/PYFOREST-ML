# %% [markdown]
# # Summary
# This code trains and evaluates a Random Forest Classifier to predict deforestation events based on land use and tree cover data. The input data consists of a stack of raster files, including land use plans, tree cover, and historical deforestation data. The model uses these raster files to predict deforestation events for the year 2012.
#
# The input raster data is flattened and stacked into a single 2D array, X_flat. `NoData` values are removed from the input data (X_cleaned) and the target variable (y_cleaned) before splitting them into training and testing datasets.
#
# The Random Forest Classifier is trained using the X_train and y_train datasets, and its performance is evaluated using cross-validation. The trained model is then used to predict deforestation events for the testing dataset (X_test). The model's performance is assessed using confusion matrices and classification reports for both the training and testing datasets.
#
# Finally, the feature importances of the input variables (e.g., land use plans, tree cover) are calculated and visualized in a bar chart to understand the relative importance of each input variable in predicting deforestation events.

# %% [markdown]
# # Import Libraries and Constants

# %%
import os
import re
import sys
import numpy as np
import pandas as pd
import tempfile
import shutil
import matplotlib.pyplot as plt
import rasterio

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (confusion_matrix, classification_report, accuracy_score, 
                             precision_score, recall_score, f1_score, roc_auc_score, 
                             precision_recall_curve, roc_curve, auc)
from sklearn.model_selection import (train_test_split, cross_val_score,
                                     GridSearchCV, RandomizedSearchCV)
from scipy.stats import randint as sp_randint

from imblearn.ensemble import BalancedRandomForestClassifier
import joblib
from joblib import dump

# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=UserWarning)
simplefilter(action='ignore', category=FutureWarning)

# %%
# Get the current working directory
current_dir = os.path.abspath('')

# Search for the 'constants.py' file starting from the current directory and moving up the hierarchy
project_root = current_dir
while not os.path.isfile(os.path.join(project_root, 'constants.py')):
    project_root = os.path.dirname(project_root)

# Add the project root to the Python path
sys.path.append(project_root)

# %%
from constants import SERVER_PATH, OUTPUT_PATH, MASKED_RASTERS_DIR, FEATURES_DIR

# %%
#output- update this for subsequent runs
output_folder = os.path.join(OUTPUT_PATH[0], 'brfc-features-model')

# %% [markdown]
# # Create Stack

# %%
# helper function to read tiff files
def read_tiff_image(file_path):
    with rasterio.open(file_path) as src:
        return src.read(1)

# %%
# List of paths to the raster files excluding 'deforestation11_20_masked.tif'
feature_files = [os.path.join(FEATURES_DIR[0], file_name) for file_name in os.listdir(FEATURES_DIR[0])]

# Then you can use this list of raster_files to create feature_data_arrays and raster_data_flat:
feature_data_arrays = [read_tiff_image(file_path) for file_path in feature_files]
feature_data_flat = [data_array.flatten() for data_array in feature_data_arrays]

# Path to the y_file
y_file = os.path.join(MASKED_RASTERS_DIR[0], 'deforestation11_20_masked.tif')

# %%
feature_files
# Out:
# ['/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/soil_treemask.tif',
#  '/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/road_treemask.tif',
#  '/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/lup_10_treemask.tif',
#  '/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/precipitation_treemask.tif',
#  '/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/river_treemask.tif',
#  '/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/cities_treemask.tif',
#  '/Users/romero61/../../capstone/pyforest/ml_data/output/tree_masked_rasters/ports_treemask.tif']

# %%
y_file
# Out:
# '/Users/romero61/../../capstone/pyforest/ml_data/output/masked_rasters/deforestation11_20_masked.tif'

# %%
# Find the dimensions of all the raster data arrays
raster_shapes = [raster_data.shape for raster_data in feature_data_arrays]

# Check if all raster data arrays have the same dimensions
if len(set(raster_shapes)) > 1:
    print("There are mismatching dimensions:")
    for file_path, raster_shape in zip(raster_files, raster_shapes):
        print(f"File: {file_path}, Shape: {raster_shape}")
else:
    print("All raster data arrays have the same dimensions.")
    # Check the dimensions of all the raster data arrays
    for i, data_array in enumerate(feature_data_arrays):
        print(f"Raster {i}: {data_array.shape}")
# Out:
# All raster data arrays have the same dimensions.
# Raster 0: (22512, 20381)
# Raster 1: (22512, 20381)
# Raster 2: (22512, 20381)
# Raster 3: (22512, 20381)
# Raster 4: (22512, 20381)
# Raster 5: (22512, 20381)
# Raster 6: (22512, 20381)

# %% [markdown]
# # Stack and Flatten Data

# %%
# NoData Value
no_data_value = -1

# Stack the flattened raster data
X_flat = np.column_stack(feature_data_flat)

# Use the y_file obtained from the find_deforestation_file function
y = read_tiff_image(y_file).flatten()

# Remove rows with NoData values
'''checks each row in X_flat and creates a boolean array (valid_rows_X) that has the same number of elements 
as the number of rows in X_flat. Each element in valid_rows_X is True if there is no NoData value in 
the corresponding row of X_flat and False otherwise.'''
valid_rows_X = ~(X_flat == no_data_value).any(axis=1)

'''checks each element in the y array and creates a boolean array (valid_rows_y) that has the same number of 
elements as y. Each element in valid_rows_y is True if the corresponding element in y is not 
equal to the NoData value and False otherwise.'''
valid_rows_y = y != no_data_value

'''checks each element in the y array and creates a boolean array (valid_rows_y) 
that has the same number of elements as y. Each element in valid_rows_y is True if the corresponding element 
in y is not equal to the NoData value and False otherwise.'''
valid_rows = valid_rows_X & valid_rows_y

'''creates a new array X_cleaned by selecting only the rows in X_flat that 
correspond to the True elements in valid_rows.'''
X_cleaned = X_flat[valid_rows]

'''creates a new array y_cleaned by selecting only the elements in y that correspond 
to the True elements in valid_rows.'''
y_cleaned = y[valid_rows]

# %% [markdown]
# To ensure your data cleaning steps have been applied correctly, you can check the following:
#
# **NoData values have been removed:** You should confirm that there are no NoData values in your cleaned data. This can be done by asserting that there are no occurrences of no_data_value in X_cleaned and y_cleaned.

# %%
assert not (X_cleaned == no_data_value).any()
assert not (y_cleaned == no_data_value).any()

# %% [markdown]
# These assertions will throw an error if there is a NoData value in X_cleaned or y_cleaned
#
# **Dimensions are correct:** The shapes of X_cleaned and y_cleaned should match along the row dimension (the first dimension for 2D array X_cleaned and the only dimension for 1D array y_cleaned).

# %%
print("Shape of X_cleaned:", X_cleaned.shape)
print("Shape of y_cleaned:", y_cleaned.shape)
# Out:
# Shape of X_cleaned: (29112890, 7)
# Shape of y_cleaned: (29112890,)

# %% [markdown]
# Make sure the number of rows in X_cleaned equals the number of elements in y_cleaned.
#
# **Confirm that the valid rows have been correctly identified:** You can do this by checking that the number of True values in valid_rows equals the number of rows in X_cleaned (or the number of elements in y_cleaned).

# %%
assert valid_rows.sum() == X_cleaned.shape[0]

# %% [markdown]
# # Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_cleaned, y_cleaned, test_size=0.3, random_state=42, stratify=y_cleaned)

# %%
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of y_test: (8733867,)

# %% [markdown]
# # Class Balance Check

# %%
# Create pandas Series from your labels
y_train_series = pd.Series(y_train)
y_test_series = pd.Series(y_test)
y_cleaned_series = pd.Series(y_cleaned)

# Print balance of classes in training, testing, and whole dataset
print("Training data balance:\n", y_train_series.value_counts(normalize=True))
print("Testing data balance:\n", y_test_series.value_counts(normalize=True))
print("Whole dataset balance:\n", y_cleaned_series.value_counts(normalize=True))
# Out:
# Training data balance:
#  0    0.747872
# 1    0.252128
# dtype: float64
# Testing data balance:
#  0    0.747872
# 1    0.252128
# dtype: float64
# Whole dataset balance:
#  0    0.747872
# 1    0.252128
# dtype: float64

# %%
# Create a list to hold your feature file paths


# Define the labels for your features
feature_labels = [ 'SOIL', 'ROAD', 'LUP_10', 'PRECIPITATION', 'RIVER', 'CITIES', 'PORTS' ]



for i, feature in enumerate(feature_labels):
    unique_values, counts = np.unique(X_cleaned[:, i], return_counts=True)
    
    # Print the counts for each unique value
    for value, count in zip(unique_values, counts):
        print(f'{feature} Value: {value}, Count: {count}')

    print('-----------------')
    
    # Plot histogram
    plt.figure(figsize=(10, 6))
    plt.hist(X_cleaned[:, i], bins=20)
    plt.title(f'{feature} Distribution')
    plt.xlabel('Values')
    plt.ylabel('Counts')
    plt.show()
# Out:
# SOIL Value: 0.0, Count: 37731
# SOIL Value: 4.0, Count: 83618
# SOIL Value: 6.0, Count: 210035
# SOIL Value: 10.0, Count: 1008873
# SOIL Value: 11.0, Count: 14349919
# SOIL Value: 12.0, Count: 497698
# SOIL Value: 15.0, Count: 3987
# SOIL Value: 16.0, Count: 47218
# SOIL Value: 17.0, Count: 24247
# SOIL Value: 18.0, Count: 1373366
# SOIL Value: 20.0, Count: 133
# SOIL Value: 21.0, Count: 4196784
# SOIL Value: 22.0, Count: 92
# SOIL Value: 25.0, Count: 64
# SOIL Value: 26.0, Count: 5416677
# SOIL Value: 29.0, Count: 1862448
# -----------------
# ROAD Value: 0.0, Count: 225402
# ROAD Value: 1.0, Count: 147340
# ROAD Value: 2.0, Count: 146223
# ROAD Value: 3.0, Count: 125058
# ROAD Value: 4.0, Count: 122931
# ROAD Value: 5.0, Count: 140458
# ROAD Value: 6.0, Count: 120964
# ROAD Value: 7.0, Count: 127205
# ROAD Value: 8.0, Count: 130431
# ROAD Value: 9.0, Count: 122226
# ROAD Value: 10.0, Count: 119709
# ROAD Value: 11.0, Count: 116467
# ROAD Value: 12.0, Count: 122583
# ROAD Value: 13.0, Count: 126116
# ROAD Value: 14.0, Count: 118307
# ROAD Value: 15.0, Count: 115603
# ROAD Value: 16.0, Count: 116768
# ROAD Value: 17.0, Count: 117861
# ROAD Value: 18.0, Count: 119198
# ROAD Value: 19.0, Count: 114822
# ROAD Value: 20.0, Count: 112816
# ROAD Value: 21.0, Count: 119020
# ROAD Value: 22.0, Count: 111240
# ROAD Value: 23.0, Count: 111504
# ROAD Value: 24.0, Count: 112744
# ROAD Value: 25.0, Count: 117657
# ROAD Value: 26.0, Count: 113856
# ROAD Value: 27.0, Count: 107657
# ROAD Value: 28.0, Count: 108533
# ROAD Value: 29.0, Count: 113140
# ROAD Value: 30.0, Count: 108114
# ROAD Value: 31.0, Count: 112470
# ROAD Value: 32.0, Count: 109215
# ROAD Value: 33.0, Count: 110381
# ROAD Value: 34.0, Count: 110697
# ROAD Value: 35.0, Count: 105863
# ROAD Value: 36.0, Count: 109780
# ROAD Value: 37.0, Count: 106989
# ROAD Value: 38.0, Count: 111185
# ROAD Value: 39.0, Count: 106678
# ROAD Value: 40.0, Count: 103965
# ROAD Value: 41.0, Count: 110945
# ROAD Value: 42.0, Count: 105598
# ROAD Value: 43.0, Count: 107394
# ROAD Value: 44.0, Count: 103818
# ROAD Value: 45.0, Count: 103291
# ROAD Value: 46.0, Count: 104799
# ROAD Value: 47.0, Count: 101987
# ROAD Value: 48.0, Count: 104850
# ROAD Value: 49.0, Count: 104097
# ROAD Value: 50.0, Count: 108621
# ROAD Value: 51.0, Count: 102266
# ROAD Value: 52.0, Count: 100180
# ROAD Value: 53.0, Count: 102619
# ROAD Value: 54.0, Count: 98656
# ROAD Value: 55.0, Count: 103719
# ROAD Value: 56.0, Count: 98348
# ROAD Value: 57.0, Count: 101276
# ROAD Value: 58.0, Count: 97567
# ROAD Value: 59.0, Count: 98983
# ROAD Value: 60.0, Count: 99632
# ROAD Value: 61.0, Count: 99712
# ROAD Value: 62.0, Count: 99162
# ROAD Value: 63.0, Count: 97096
# ROAD Value: 64.0, Count: 95765
# ROAD Value: 65.0, Count: 98990
# ROAD Value: 66.0, Count: 95109
# ROAD Value: 67.0, Count: 97936
# ROAD Value: 68.0, Count: 95993
# ROAD Value: 69.0, Count: 93292
# ROAD Value: 70.0, Count: 95883
# ROAD Value: 71.0, Count: 93610
# ROAD Value: 72.0, Count: 99414
# ROAD Value: 73.0, Count: 93729
# ROAD Value: 74.0, Count: 94110
# ROAD Value: 75.0, Count: 92050
# ROAD Value: 76.0, Count: 92329
# ROAD Value: 77.0, Count: 92835
# ROAD Value: 78.0, Count: 89750
# ROAD Value: 79.0, Count: 91740
# ROAD Value: 80.0, Count: 92476
# ROAD Value: 81.0, Count: 88814
# ROAD Value: 82.0, Count: 91942
# ROAD Value: 83.0, Count: 88198
# ROAD Value: 84.0, Count: 91181
# ROAD Value: 85.0, Count: 90904
# ROAD Value: 86.0, Count: 89582
# ROAD Value: 87.0, Count: 89232
# ROAD Value: 88.0, Count: 87309
# ROAD Value: 89.0, Count: 91981
# ROAD Value: 90.0, Count: 87453
# ROAD Value: 91.0, Count: 87928
# ROAD Value: 92.0, Count: 86939
# ROAD Value: 93.0, Count: 85494
# ROAD Value: 94.0, Count: 86202
# ROAD Value: 95.0, Count: 83130
# ROAD Value: 96.0, Count: 83690
# ROAD Value: 97.0, Count: 84758
# ROAD Value: 98.0, Count: 84004
# ROAD Value: 99.0, Count: 83123
# ROAD Value: 100.0, Count: 80929
# ROAD Value: 101.0, Count: 83231
# ROAD Value: 102.0, Count: 80283
# ROAD Value: 103.0, Count: 78473
# ROAD Value: 104.0, Count: 80134
# ROAD Value: 105.0, Count: 79017
# ROAD Value: 106.0, Count: 80083
# ROAD Value: 107.0, Count: 78375
# ROAD Value: 108.0, Count: 77034
# ROAD Value: 109.0, Count: 77215
# ROAD Value: 110.0, Count: 76523
# ROAD Value: 111.0, Count: 76474
# ROAD Value: 112.0, Count: 74951
# ROAD Value: 113.0, Count: 75952
# ROAD Value: 114.0, Count: 75153
# ROAD Value: 115.0, Count: 74006
# ROAD Value: 116.0, Count: 72495
# ROAD Value: 117.0, Count: 74009
# ROAD Value: 118.0, Count: 74318
# ROAD Value: 119.0, Count: 73254
# ROAD Value: 120.0, Count: 73541
# ROAD Value: 121.0, Count: 71719
# ROAD Value: 122.0, Count: 74118
# ROAD Value: 123.0, Count: 74326
# ROAD Value: 124.0, Count: 70510
# ROAD Value: 125.0, Count: 72558
# ROAD Value: 126.0, Count: 69424
# ROAD Value: 127.0, Count: 72607
# ROAD Value: 128.0, Count: 71861
# ROAD Value: 129.0, Count: 68917
# ROAD Value: 130.0, Count: 71029
# ROAD Value: 131.0, Count: 68666
# ROAD Value: 132.0, Count: 70026
# ROAD Value: 133.0, Count: 67431
# ROAD Value: 134.0, Count: 65077
# ROAD Value: 135.0, Count: 68721
# ROAD Value: 136.0, Count: 65968
# ROAD Value: 137.0, Count: 67122
# ROAD Value: 138.0, Count: 66079
# ROAD Value: 139.0, Count: 65573
# ROAD Value: 140.0, Count: 67195
# ROAD Value: 141.0, Count: 65464
# ROAD Value: 142.0, Count: 66925
# ROAD Value: 143.0, Count: 66099
# ROAD Value: 144.0, Count: 64980
# ROAD Value: 145.0, Count: 65001
# ROAD Value: 146.0, Count: 63002
# ROAD Value: 147.0, Count: 62491
# ROAD Value: 148.0, Count: 63672
# ROAD Value: 149.0, Count: 62000
# ROAD Value: 150.0, Count: 61888
# ROAD Value: 151.0, Count: 60761
# ROAD Value: 152.0, Count: 61860
# ROAD Value: 153.0, Count: 60596
# ROAD Value: 154.0, Count: 62022
# ROAD Value: 155.0, Count: 60708
# ROAD Value: 156.0, Count: 61438
# ROAD Value: 157.0, Count: 60816
# ROAD Value: 158.0, Count: 59528
# ROAD Value: 159.0, Count: 60079
# ROAD Value: 160.0, Count: 60337
# ROAD Value: 161.0, Count: 61461
# ROAD Value: 162.0, Count: 59890
# ROAD Value: 163.0, Count: 59275
# ROAD Value: 164.0, Count: 60084
# ROAD Value: 165.0, Count: 59997
# ROAD Value: 166.0, Count: 60883
# ROAD Value: 167.0, Count: 58238
# ROAD Value: 168.0, Count: 58106
# ROAD Value: 169.0, Count: 59998
# ROAD Value: 170.0, Count: 58717
# ROAD Value: 171.0, Count: 58473
# ROAD Value: 172.0, Count: 56686
# ROAD Value: 173.0, Count: 58553
# ROAD Value: 174.0, Count: 56645
# ROAD Value: 175.0, Count: 56053
# ROAD Value: 176.0, Count: 56782
# ROAD Value: 177.0, Count: 55523
# ROAD Value: 178.0, Count: 56760
# ROAD Value: 179.0, Count: 55129
# ROAD Value: 180.0, Count: 54819
# ROAD Value: 181.0, Count: 56036
# ROAD Value: 182.0, Count: 55843
# ROAD Value: 183.0, Count: 56157
# ROAD Value: 184.0, Count: 53907
# ROAD Value: 185.0, Count: 55224
# ROAD Value: 186.0, Count: 55770
# ROAD Value: 187.0, Count: 53838
# ROAD Value: 188.0, Count: 54592
# ROAD Value: 189.0, Count: 53851
# ROAD Value: 190.0, Count: 54400
# ROAD Value: 191.0, Count: 54162
# ROAD Value: 192.0, Count: 51741
# ROAD Value: 193.0, Count: 52839
# ROAD Value: 194.0, Count: 51608
# ROAD Value: 195.0, Count: 51890
# ROAD Value: 196.0, Count: 51625
# ROAD Value: 197.0, Count: 50845
# ROAD Value: 198.0, Count: 51222
# ROAD Value: 199.0, Count: 50534
# ROAD Value: 200.0, Count: 51972
# ROAD Value: 201.0, Count: 50414
# ROAD Value: 202.0, Count: 50074
# ROAD Value: 203.0, Count: 51480
# ROAD Value: 204.0, Count: 49711
# ROAD Value: 205.0, Count: 50151
# ROAD Value: 206.0, Count: 48988
# ROAD Value: 207.0, Count: 49406
# ROAD Value: 208.0, Count: 49207
# ROAD Value: 209.0, Count: 48736
# ROAD Value: 210.0, Count: 47654
# ROAD Value: 211.0, Count: 48596
# ROAD Value: 212.0, Count: 47064
# ROAD Value: 213.0, Count: 47357
# ROAD Value: 214.0, Count: 47290
# ROAD Value: 215.0, Count: 46180
# ROAD Value: 216.0, Count: 47612
# ROAD Value: 217.0, Count: 47060
# ROAD Value: 218.0, Count: 46786
# ROAD Value: 219.0, Count: 46840
# ROAD Value: 220.0, Count: 46143
# ROAD Value: 221.0, Count: 46543
# ROAD Value: 222.0, Count: 46352
# ROAD Value: 223.0, Count: 45353
# ROAD Value: 224.0, Count: 46280
# ROAD Value: 225.0, Count: 44446
# ROAD Value: 226.0, Count: 45291
# ROAD Value: 227.0, Count: 44045
# ROAD Value: 228.0, Count: 44519
# ROAD Value: 229.0, Count: 44626
# ROAD Value: 230.0, Count: 42379
# ROAD Value: 231.0, Count: 43016
# ROAD Value: 232.0, Count: 42647
# ROAD Value: 233.0, Count: 42606
# ROAD Value: 234.0, Count: 43342
# ROAD Value: 235.0, Count: 42048
# ROAD Value: 236.0, Count: 42335
# ROAD Value: 237.0, Count: 42850
# ROAD Value: 238.0, Count: 41451
# ROAD Value: 239.0, Count: 42444
# ROAD Value: 240.0, Count: 41313
# ROAD Value: 241.0, Count: 43108
# ROAD Value: 242.0, Count: 42653
# ROAD Value: 243.0, Count: 41104
# ROAD Value: 244.0, Count: 41934
# ROAD Value: 245.0, Count: 41212
# ROAD Value: 246.0, Count: 42769
# ROAD Value: 247.0, Count: 41341
# ROAD Value: 248.0, Count: 40799
# ROAD Value: 249.0, Count: 41342
# ROAD Value: 250.0, Count: 40554
# ROAD Value: 251.0, Count: 41134
# ROAD Value: 252.0, Count: 41056
# ROAD Value: 253.0, Count: 40877
# ROAD Value: 254.0, Count: 41572
# ROAD Value: 255.0, Count: 41872
# ROAD Value: 256.0, Count: 40680
# ROAD Value: 257.0, Count: 41009
# ROAD Value: 258.0, Count: 41662
# ROAD Value: 259.0, Count: 40758
# ROAD Value: 260.0, Count: 40693
# ROAD Value: 261.0, Count: 40087
# ROAD Value: 262.0, Count: 40360
# ROAD Value: 263.0, Count: 39504
# ROAD Value: 264.0, Count: 39466
# ROAD Value: 265.0, Count: 40065
# ROAD Value: 266.0, Count: 39405
# ROAD Value: 267.0, Count: 39567
# ROAD Value: 268.0, Count: 39277
# ROAD Value: 269.0, Count: 39074
# ROAD Value: 270.0, Count: 38962
# ROAD Value: 271.0, Count: 39124
# ROAD Value: 272.0, Count: 38744
# ROAD Value: 273.0, Count: 37807
# ROAD Value: 274.0, Count: 37757
# ROAD Value: 275.0, Count: 38133
# ROAD Value: 276.0, Count: 36593
# ROAD Value: 277.0, Count: 36864
# ROAD Value: 278.0, Count: 35897
# ROAD Value: 279.0, Count: 36463
# ROAD Value: 280.0, Count: 35890
# ROAD Value: 281.0, Count: 34900
# ROAD Value: 282.0, Count: 34992
# ROAD Value: 283.0, Count: 34589
# ROAD Value: 284.0, Count: 34745
# ROAD Value: 285.0, Count: 34102
# ROAD Value: 286.0, Count: 33322
# ROAD Value: 287.0, Count: 33986
# ROAD Value: 288.0, Count: 34028
# ROAD Value: 289.0, Count: 33400
# ROAD Value: 290.0, Count: 33420
# ROAD Value: 291.0, Count: 31717
# ROAD Value: 292.0, Count: 33518
# ROAD Value: 293.0, Count: 31932
# ROAD Value: 294.0, Count: 32005
# ROAD Value: 295.0, Count: 31897
# ROAD Value: 296.0, Count: 32110
# ROAD Value: 297.0, Count: 31887
# ROAD Value: 298.0, Count: 31169
# ROAD Value: 299.0, Count: 31117
# ROAD Value: 300.0, Count: 31385
# ROAD Value: 301.0, Count: 30645
# ROAD Value: 302.0, Count: 31415
# ROAD Value: 303.0, Count: 30286
# ROAD Value: 304.0, Count: 30035
# ROAD Value: 305.0, Count: 30613
# ROAD Value: 306.0, Count: 29263
# ROAD Value: 307.0, Count: 29559
# ROAD Value: 308.0, Count: 28981
# ROAD Value: 309.0, Count: 30098
# ROAD Value: 310.0, Count: 29190
# ROAD Value: 311.0, Count: 28995
# ROAD Value: 312.0, Count: 28597
# ROAD Value: 313.0, Count: 29603
# ROAD Value: 314.0, Count: 29774
# ROAD Value: 315.0, Count: 29250
# ROAD Value: 316.0, Count: 28646
# ROAD Value: 317.0, Count: 28977
# ROAD Value: 318.0, Count: 28844
# ROAD Value: 319.0, Count: 28479
# ROAD Value: 320.0, Count: 28406
# ROAD Value: 321.0, Count: 28229
# ROAD Value: 322.0, Count: 28538
# ROAD Value: 323.0, Count: 28147
# ROAD Value: 324.0, Count: 27526
# ROAD Value: 325.0, Count: 27868
# ROAD Value: 326.0, Count: 27631
# ROAD Value: 327.0, Count: 27948
# ROAD Value: 328.0, Count: 27420
# ROAD Value: 329.0, Count: 27047
# ROAD Value: 330.0, Count: 27457
# ROAD Value: 331.0, Count: 26856
# ROAD Value: 332.0, Count: 26887
# ROAD Value: 333.0, Count: 27214
# ROAD Value: 334.0, Count: 26697
# ROAD Value: 335.0, Count: 26659
# ROAD Value: 336.0, Count: 26147
# ROAD Value: 337.0, Count: 26225
# ROAD Value: 338.0, Count: 27167
# ROAD Value: 339.0, Count: 25844
# ROAD Value: 340.0, Count: 26193
# ROAD Value: 341.0, Count: 25602
# ROAD Value: 342.0, Count: 25237
# ROAD Value: 343.0, Count: 25630
# ROAD Value: 344.0, Count: 24536
# ROAD Value: 345.0, Count: 25358
# ROAD Value: 346.0, Count: 24943
# ROAD Value: 347.0, Count: 25269
# ROAD Value: 348.0, Count: 25138
# ROAD Value: 349.0, Count: 24555
# ROAD Value: 350.0, Count: 25150
# ROAD Value: 351.0, Count: 24882
# ROAD Value: 352.0, Count: 24779
# ROAD Value: 353.0, Count: 25015
# ROAD Value: 354.0, Count: 24410
# ROAD Value: 355.0, Count: 24923
# ROAD Value: 356.0, Count: 24277
# ROAD Value: 357.0, Count: 24675
# ROAD Value: 358.0, Count: 24135
# ROAD Value: 359.0, Count: 23897
# ROAD Value: 360.0, Count: 24398
# ROAD Value: 361.0, Count: 23965
# ROAD Value: 362.0, Count: 24101
# ROAD Value: 363.0, Count: 23461
# ROAD Value: 364.0, Count: 23852
# ROAD Value: 365.0, Count: 23350
# ROAD Value: 366.0, Count: 23112
# ROAD Value: 367.0, Count: 22597
# ROAD Value: 368.0, Count: 22920
# ROAD Value: 369.0, Count: 22870
# ROAD Value: 370.0, Count: 22620
# ROAD Value: 371.0, Count: 22610
# ROAD Value: 372.0, Count: 22418
# ROAD Value: 373.0, Count: 22493
# ROAD Value: 374.0, Count: 22416
# ROAD Value: 375.0, Count: 22036
# ROAD Value: 376.0, Count: 21857
# ROAD Value: 377.0, Count: 21900
# ROAD Value: 378.0, Count: 21697
# ROAD Value: 379.0, Count: 21514
# ROAD Value: 380.0, Count: 21226
# ROAD Value: 381.0, Count: 21697
# ROAD Value: 382.0, Count: 21458
# ROAD Value: 383.0, Count: 21509
# ROAD Value: 384.0, Count: 21591
# ROAD Value: 385.0, Count: 21439
# ROAD Value: 386.0, Count: 21511
# ROAD Value: 387.0, Count: 21147
# ROAD Value: 388.0, Count: 21527
# ROAD Value: 389.0, Count: 21256
# ROAD Value: 390.0, Count: 20875
# ROAD Value: 391.0, Count: 21044
# ROAD Value: 392.0, Count: 20753
# ROAD Value: 393.0, Count: 20879
# ROAD Value: 394.0, Count: 20894
# ROAD Value: 395.0, Count: 20293
# ROAD Value: 396.0, Count: 20574
# ROAD Value: 397.0, Count: 20161
# ROAD Value: 398.0, Count: 20559
# ROAD Value: 399.0, Count: 20130
# ROAD Value: 400.0, Count: 19823
# ROAD Value: 401.0, Count: 20032
# ROAD Value: 402.0, Count: 19518
# ROAD Value: 403.0, Count: 19506
# ROAD Value: 404.0, Count: 19357
# ROAD Value: 405.0, Count: 19034
# ROAD Value: 406.0, Count: 19218
# ROAD Value: 407.0, Count: 18936
# ROAD Value: 408.0, Count: 18983
# ROAD Value: 409.0, Count: 18710
# ROAD Value: 410.0, Count: 18887
# ROAD Value: 411.0, Count: 19005
# ROAD Value: 412.0, Count: 18725
# ROAD Value: 413.0, Count: 18512
# ROAD Value: 414.0, Count: 18625
# ROAD Value: 415.0, Count: 18933
# ROAD Value: 416.0, Count: 18597
# ROAD Value: 417.0, Count: 18820
# ROAD Value: 418.0, Count: 18669
# ROAD Value: 419.0, Count: 18997
# ROAD Value: 420.0, Count: 18638
# ROAD Value: 421.0, Count: 18639
# ROAD Value: 422.0, Count: 18465
# ROAD Value: 423.0, Count: 18215
# ROAD Value: 424.0, Count: 18310
# ROAD Value: 425.0, Count: 17941
# ROAD Value: 426.0, Count: 17922
# ROAD Value: 427.0, Count: 18094
# ROAD Value: 428.0, Count: 17738
# ROAD Value: 429.0, Count: 17563
# ROAD Value: 430.0, Count: 17365
# ROAD Value: 431.0, Count: 17537
# ROAD Value: 432.0, Count: 17649
# ROAD Value: 433.0, Count: 17119
# ROAD Value: 434.0, Count: 17309
# ROAD Value: 435.0, Count: 17014
# ROAD Value: 436.0, Count: 16986
# ROAD Value: 437.0, Count: 16890
# ROAD Value: 438.0, Count: 16578
# ROAD Value: 439.0, Count: 16614
# ROAD Value: 440.0, Count: 16595
# ROAD Value: 441.0, Count: 16386
# ROAD Value: 442.0, Count: 16454
# ROAD Value: 443.0, Count: 16228
# ROAD Value: 444.0, Count: 16685
# ROAD Value: 445.0, Count: 16383
# ROAD Value: 446.0, Count: 16354
# ROAD Value: 447.0, Count: 16265
# ROAD Value: 448.0, Count: 15849
# ROAD Value: 449.0, Count: 16282
# ROAD Value: 450.0, Count: 16202
# ROAD Value: 451.0, Count: 16068
# ROAD Value: 452.0, Count: 15923
# ROAD Value: 453.0, Count: 15774
# ROAD Value: 454.0, Count: 15800
# ROAD Value: 455.0, Count: 15640
# ROAD Value: 456.0, Count: 15712
# ROAD Value: 457.0, Count: 15543
# ROAD Value: 458.0, Count: 15358
# ROAD Value: 459.0, Count: 15420
# ROAD Value: 460.0, Count: 15408
# ROAD Value: 461.0, Count: 15451
# ROAD Value: 462.0, Count: 15107
# ROAD Value: 463.0, Count: 15309
# ROAD Value: 464.0, Count: 15259
# ROAD Value: 465.0, Count: 15214
# ROAD Value: 466.0, Count: 15055
# ROAD Value: 467.0, Count: 14828
# ROAD Value: 468.0, Count: 14873
# ROAD Value: 469.0, Count: 14962
# ROAD Value: 470.0, Count: 14987
# ROAD Value: 471.0, Count: 14759
# ROAD Value: 472.0, Count: 14629
# ROAD Value: 473.0, Count: 14602
# ROAD Value: 474.0, Count: 14637
# ROAD Value: 475.0, Count: 14514
# ROAD Value: 476.0, Count: 14158
# ROAD Value: 477.0, Count: 14201
# ROAD Value: 478.0, Count: 14452
# ROAD Value: 479.0, Count: 14127
# ROAD Value: 480.0, Count: 14057
# ROAD Value: 481.0, Count: 13884
# ROAD Value: 482.0, Count: 13858
# ROAD Value: 483.0, Count: 13752
# ROAD Value: 484.0, Count: 13353
# ROAD Value: 485.0, Count: 13699
# ROAD Value: 486.0, Count: 13348
# ROAD Value: 487.0, Count: 13609
# ROAD Value: 488.0, Count: 13410
# ROAD Value: 489.0, Count: 12936
# ROAD Value: 490.0, Count: 13007
# ROAD Value: 491.0, Count: 12817
# ROAD Value: 492.0, Count: 12871
# ROAD Value: 493.0, Count: 12799
# ROAD Value: 494.0, Count: 12469
# ROAD Value: 495.0, Count: 12882
# ROAD Value: 496.0, Count: 12515
# ROAD Value: 497.0, Count: 12889
# ROAD Value: 498.0, Count: 12775
# ROAD Value: 499.0, Count: 12839
# ROAD Value: 500.0, Count: 12878
# ROAD Value: 501.0, Count: 12650
# ROAD Value: 502.0, Count: 12980
# ROAD Value: 503.0, Count: 12861
# ROAD Value: 504.0, Count: 12894
# ROAD Value: 505.0, Count: 13059
# ROAD Value: 506.0, Count: 12996
# ROAD Value: 507.0, Count: 12932
# ROAD Value: 508.0, Count: 12890
# ROAD Value: 509.0, Count: 12882
# ROAD Value: 510.0, Count: 12866
# ROAD Value: 511.0, Count: 12810
# ROAD Value: 512.0, Count: 12517
# ROAD Value: 513.0, Count: 12317
# ROAD Value: 514.0, Count: 12324
# ROAD Value: 515.0, Count: 12158
# ROAD Value: 516.0, Count: 12335
# ROAD Value: 517.0, Count: 11904
# ROAD Value: 518.0, Count: 12087
# ROAD Value: 519.0, Count: 12062
# ROAD Value: 520.0, Count: 11998
# ROAD Value: 521.0, Count: 12216
# ROAD Value: 522.0, Count: 11832
# ROAD Value: 523.0, Count: 12228
# ROAD Value: 524.0, Count: 11994
# ROAD Value: 525.0, Count: 12050
# ROAD Value: 526.0, Count: 12077
# ROAD Value: 527.0, Count: 11874
# ROAD Value: 528.0, Count: 12089
# ROAD Value: 529.0, Count: 11956
# ROAD Value: 530.0, Count: 12021
# ROAD Value: 531.0, Count: 11862
# ROAD Value: 532.0, Count: 11465
# ROAD Value: 533.0, Count: 11871
# ROAD Value: 534.0, Count: 11350
# ROAD Value: 535.0, Count: 11423
# ROAD Value: 536.0, Count: 11452
# ROAD Value: 537.0, Count: 11076
# ROAD Value: 538.0, Count: 11274
# ROAD Value: 539.0, Count: 10963
# ROAD Value: 540.0, Count: 11179
# ROAD Value: 541.0, Count: 11197
# ROAD Value: 542.0, Count: 11238
# ROAD Value: 543.0, Count: 11269
# ROAD Value: 544.0, Count: 11130
# ROAD Value: 545.0, Count: 11167
# ROAD Value: 546.0, Count: 11212
# ROAD Value: 547.0, Count: 10922
# ROAD Value: 548.0, Count: 11251
# ROAD Value: 549.0, Count: 11064
# ROAD Value: 550.0, Count: 11158
# ROAD Value: 551.0, Count: 10992
# ROAD Value: 552.0, Count: 10634
# ROAD Value: 553.0, Count: 10669
# ROAD Value: 554.0, Count: 10399
# ROAD Value: 555.0, Count: 10560
# ROAD Value: 556.0, Count: 10471
# ROAD Value: 557.0, Count: 10457
# ROAD Value: 558.0, Count: 10453
# ROAD Value: 559.0, Count: 10424
# ROAD Value: 560.0, Count: 10397
# ROAD Value: 561.0, Count: 10297
# ROAD Value: 562.0, Count: 10258
# ROAD Value: 563.0, Count: 10286
# ROAD Value: 564.0, Count: 10097
# ROAD Value: 565.0, Count: 9744
# ROAD Value: 566.0, Count: 9706
# ROAD Value: 567.0, Count: 9576
# ROAD Value: 568.0, Count: 9837
# ROAD Value: 569.0, Count: 9788
# ROAD Value: 570.0, Count: 9649
# ROAD Value: 571.0, Count: 9930
# ROAD Value: 572.0, Count: 9534
# ROAD Value: 573.0, Count: 9638
# ROAD Value: 574.0, Count: 9582
# ROAD Value: 575.0, Count: 9523
# ROAD Value: 576.0, Count: 9956
# ROAD Value: 577.0, Count: 9735
# ROAD Value: 578.0, Count: 9825
# ROAD Value: 579.0, Count: 9703
# ROAD Value: 580.0, Count: 9649
# ROAD Value: 581.0, Count: 9815
# ROAD Value: 582.0, Count: 9635
# ROAD Value: 583.0, Count: 9507
# ROAD Value: 584.0, Count: 9728
# ROAD Value: 585.0, Count: 9518
# ROAD Value: 586.0, Count: 9758
# ROAD Value: 587.0, Count: 9532
# ROAD Value: 588.0, Count: 9585
# ROAD Value: 589.0, Count: 9758
# ROAD Value: 590.0, Count: 9555
# ROAD Value: 591.0, Count: 9812
# ROAD Value: 592.0, Count: 9569
# ROAD Value: 593.0, Count: 9458
# ROAD Value: 594.0, Count: 9513
# ROAD Value: 595.0, Count: 9223
# ROAD Value: 596.0, Count: 9514
# ROAD Value: 597.0, Count: 9413
# ROAD Value: 598.0, Count: 9269
# ROAD Value: 599.0, Count: 9393
# ROAD Value: 600.0, Count: 9102
# ROAD Value: 601.0, Count: 9680
# ROAD Value: 602.0, Count: 9427
# ROAD Value: 603.0, Count: 9440
# ROAD Value: 604.0, Count: 9630
# ROAD Value: 605.0, Count: 9496
# ROAD Value: 606.0, Count: 9781
# ROAD Value: 607.0, Count: 9637
# ROAD Value: 608.0, Count: 9474
# ROAD Value: 609.0, Count: 9724
# ROAD Value: 610.0, Count: 10125
# ROAD Value: 611.0, Count: 9867
# ROAD Value: 612.0, Count: 9839
# ROAD Value: 613.0, Count: 9804
# ROAD Value: 614.0, Count: 10008
# ROAD Value: 615.0, Count: 9981
# ROAD Value: 616.0, Count: 9889
# ROAD Value: 617.0, Count: 9974
# ROAD Value: 618.0, Count: 9961
# ROAD Value: 619.0, Count: 10022
# ROAD Value: 620.0, Count: 10034
# ROAD Value: 621.0, Count: 9976
# ROAD Value: 622.0, Count: 10337
# ROAD Value: 623.0, Count: 10036
# ROAD Value: 624.0, Count: 10057
# ROAD Value: 625.0, Count: 10079
# ROAD Value: 626.0, Count: 10054
# ROAD Value: 627.0, Count: 9977
# ROAD Value: 628.0, Count: 9821
# ROAD Value: 629.0, Count: 10072
# ROAD Value: 630.0, Count: 10044
# ROAD Value: 631.0, Count: 10015
# ROAD Value: 632.0, Count: 10115
# ROAD Value: 633.0, Count: 9902
# ROAD Value: 634.0, Count: 10097
# ROAD Value: 635.0, Count: 10183
# ROAD Value: 636.0, Count: 10071
# ROAD Value: 637.0, Count: 10177
# ROAD Value: 638.0, Count: 9972
# ROAD Value: 639.0, Count: 10220
# ROAD Value: 640.0, Count: 10007
# ROAD Value: 641.0, Count: 9736
# ROAD Value: 642.0, Count: 10055
# ROAD Value: 643.0, Count: 9875
# ROAD Value: 644.0, Count: 10008
# ROAD Value: 645.0, Count: 9923
# ROAD Value: 646.0, Count: 9630
# ROAD Value: 647.0, Count: 9970
# ROAD Value: 648.0, Count: 10067
# ROAD Value: 649.0, Count: 9856
# ROAD Value: 650.0, Count: 9828
# ROAD Value: 651.0, Count: 9567
# ROAD Value: 652.0, Count: 9981
# ROAD Value: 653.0, Count: 9489
# ROAD Value: 654.0, Count: 9604
# ROAD Value: 655.0, Count: 9397
# ROAD Value: 656.0, Count: 9375
# ROAD Value: 657.0, Count: 9480
# ROAD Value: 658.0, Count: 9279
# ROAD Value: 659.0, Count: 9372
# ROAD Value: 660.0, Count: 9464
# ROAD Value: 661.0, Count: 9181
# ROAD Value: 662.0, Count: 9236
# ROAD Value: 663.0, Count: 9113
# ROAD Value: 664.0, Count: 9058
# ROAD Value: 665.0, Count: 9227
# ROAD Value: 666.0, Count: 9032
# ROAD Value: 667.0, Count: 9163
# ROAD Value: 668.0, Count: 9116
# ROAD Value: 669.0, Count: 9283
# ROAD Value: 670.0, Count: 9239
# ROAD Value: 671.0, Count: 9106
# ROAD Value: 672.0, Count: 9157
# ROAD Value: 673.0, Count: 9215
# ROAD Value: 674.0, Count: 8931
# ROAD Value: 675.0, Count: 8993
# ROAD Value: 676.0, Count: 8812
# ROAD Value: 677.0, Count: 9031
# ROAD Value: 678.0, Count: 8624
# ROAD Value: 679.0, Count: 8359
# ROAD Value: 680.0, Count: 8591
# ROAD Value: 681.0, Count: 8269
# ROAD Value: 682.0, Count: 8725
# ROAD Value: 683.0, Count: 8435
# ROAD Value: 684.0, Count: 8241
# ROAD Value: 685.0, Count: 8321
# ROAD Value: 686.0, Count: 8102
# ROAD Value: 687.0, Count: 7898
# ROAD Value: 688.0, Count: 8012
# ROAD Value: 689.0, Count: 7840
# ROAD Value: 690.0, Count: 8112
# ROAD Value: 691.0, Count: 7930
# ROAD Value: 692.0, Count: 7964
# ROAD Value: 693.0, Count: 8145
# ROAD Value: 694.0, Count: 7959
# ROAD Value: 695.0, Count: 8173
# ROAD Value: 696.0, Count: 7986
# ROAD Value: 697.0, Count: 8009
# ROAD Value: 698.0, Count: 8195
# ROAD Value: 699.0, Count: 7852
# ROAD Value: 700.0, Count: 8117
# ROAD Value: 701.0, Count: 7991
# ROAD Value: 702.0, Count: 7913
# ROAD Value: 703.0, Count: 8249
# ROAD Value: 704.0, Count: 7874
# ROAD Value: 705.0, Count: 7906
# ROAD Value: 706.0, Count: 7566
# ROAD Value: 707.0, Count: 7741
# ROAD Value: 708.0, Count: 7501
# ROAD Value: 709.0, Count: 7295
# ROAD Value: 710.0, Count: 7406
# ROAD Value: 711.0, Count: 7417
# ROAD Value: 712.0, Count: 7198
# ROAD Value: 713.0, Count: 7190
# ROAD Value: 714.0, Count: 6993
# ROAD Value: 715.0, Count: 7298
# ROAD Value: 716.0, Count: 6996
# ROAD Value: 717.0, Count: 6947
# ROAD Value: 718.0, Count: 7033
# ROAD Value: 719.0, Count: 7015
# ROAD Value: 720.0, Count: 7197
# ROAD Value: 721.0, Count: 7072
# ROAD Value: 722.0, Count: 6963
# ROAD Value: 723.0, Count: 7019
# ROAD Value: 724.0, Count: 7147
# ROAD Value: 725.0, Count: 6880
# ROAD Value: 726.0, Count: 6952
# ROAD Value: 727.0, Count: 6804
# ROAD Value: 728.0, Count: 6910
# ROAD Value: 729.0, Count: 6713
# ROAD Value: 730.0, Count: 6550
# ROAD Value: 731.0, Count: 6562
# ROAD Value: 732.0, Count: 6594
# ROAD Value: 733.0, Count: 6621
# ROAD Value: 734.0, Count: 6531
# ROAD Value: 735.0, Count: 6371
# ROAD Value: 736.0, Count: 6433
# ROAD Value: 737.0, Count: 6550
# ROAD Value: 738.0, Count: 6450
# ROAD Value: 739.0, Count: 6405
# ROAD Value: 740.0, Count: 6251
# ROAD Value: 741.0, Count: 6567
# ROAD Value: 742.0, Count: 6080
# ROAD Value: 743.0, Count: 6169
# ROAD Value: 744.0, Count: 6187
# ROAD Value: 745.0, Count: 6078
# ROAD Value: 746.0, Count: 5957
# ROAD Value: 747.0, Count: 5675
# ROAD Value: 748.0, Count: 5822
# ROAD Value: 749.0, Count: 5926
# ROAD Value: 750.0, Count: 5680
# ROAD Value: 751.0, Count: 5717
# ROAD Value: 752.0, Count: 5548
# ROAD Value: 753.0, Count: 5697
# ROAD Value: 754.0, Count: 5777
# ROAD Value: 755.0, Count: 5515
# ROAD Value: 756.0, Count: 5560
# ROAD Value: 757.0, Count: 5461
# ROAD Value: 758.0, Count: 5767
# ROAD Value: 759.0, Count: 5558
# ROAD Value: 760.0, Count: 5554
# ROAD Value: 761.0, Count: 5634
# ROAD Value: 762.0, Count: 5657
# ROAD Value: 763.0, Count: 5576
# ROAD Value: 764.0, Count: 5632
# ROAD Value: 765.0, Count: 5584
# ROAD Value: 766.0, Count: 5682
# ROAD Value: 767.0, Count: 5587
# ROAD Value: 768.0, Count: 5544
# ROAD Value: 769.0, Count: 5554
# ROAD Value: 770.0, Count: 5605
# ROAD Value: 771.0, Count: 5607
# ROAD Value: 772.0, Count: 5479
# ROAD Value: 773.0, Count: 5363
# ROAD Value: 774.0, Count: 5401
# ROAD Value: 775.0, Count: 5496
# ROAD Value: 776.0, Count: 5466
# ROAD Value: 777.0, Count: 5443
# ROAD Value: 778.0, Count: 5274
# ROAD Value: 779.0, Count: 5568
# ROAD Value: 780.0, Count: 5272
# ROAD Value: 781.0, Count: 5363
# ROAD Value: 782.0, Count: 5349
# ROAD Value: 783.0, Count: 5415
# ROAD Value: 784.0, Count: 5423
# ROAD Value: 785.0, Count: 5294
# ROAD Value: 786.0, Count: 5292
# ROAD Value: 787.0, Count: 5437
# ROAD Value: 788.0, Count: 5262
# ROAD Value: 789.0, Count: 5400
# ROAD Value: 790.0, Count: 5148
# ROAD Value: 791.0, Count: 5259
# ROAD Value: 792.0, Count: 5451
# ROAD Value: 793.0, Count: 5146
# ROAD Value: 794.0, Count: 5423
# ROAD Value: 795.0, Count: 5247
# ROAD Value: 796.0, Count: 5452
# ROAD Value: 797.0, Count: 5394
# ROAD Value: 798.0, Count: 5252
# ROAD Value: 799.0, Count: 5496
# ROAD Value: 800.0, Count: 5533
# ROAD Value: 801.0, Count: 5439
# ROAD Value: 802.0, Count: 5432
# ROAD Value: 803.0, Count: 5394
# ROAD Value: 804.0, Count: 5643
# ROAD Value: 805.0, Count: 5473
# ROAD Value: 806.0, Count: 5395
# ROAD Value: 807.0, Count: 5435
# ROAD Value: 808.0, Count: 5321
# ROAD Value: 809.0, Count: 5528
# ROAD Value: 810.0, Count: 5329
# ROAD Value: 811.0, Count: 5330
# ROAD Value: 812.0, Count: 5303
# ROAD Value: 813.0, Count: 5409
# ROAD Value: 814.0, Count: 5434
# ROAD Value: 815.0, Count: 5426
# ROAD Value: 816.0, Count: 5427
# ROAD Value: 817.0, Count: 5590
# ROAD Value: 818.0, Count: 5486
# ROAD Value: 819.0, Count: 5424
# ROAD Value: 820.0, Count: 5471
# ROAD Value: 821.0, Count: 5551
# ROAD Value: 822.0, Count: 5529
# ROAD Value: 823.0, Count: 5483
# ROAD Value: 824.0, Count: 5523
# ROAD Value: 825.0, Count: 5550
# ROAD Value: 826.0, Count: 5500
# ROAD Value: 827.0, Count: 5225
# ROAD Value: 828.0, Count: 5291
# ROAD Value: 829.0, Count: 5269
# ROAD Value: 830.0, Count: 5468
# ROAD Value: 831.0, Count: 5224
# ROAD Value: 832.0, Count: 5193
# ROAD Value: 833.0, Count: 5218
# ROAD Value: 834.0, Count: 5263
# ROAD Value: 835.0, Count: 5212
# ROAD Value: 836.0, Count: 5142
# ROAD Value: 837.0, Count: 5100
# ROAD Value: 838.0, Count: 5257
# ROAD Value: 839.0, Count: 4988
# ROAD Value: 840.0, Count: 5027
# ROAD Value: 841.0, Count: 5020
# ROAD Value: 842.0, Count: 5080
# ROAD Value: 843.0, Count: 5038
# ROAD Value: 844.0, Count: 4934
# ROAD Value: 845.0, Count: 5018
# ROAD Value: 846.0, Count: 4920
# ROAD Value: 847.0, Count: 5057
# ROAD Value: 848.0, Count: 4821
# ROAD Value: 849.0, Count: 4779
# ROAD Value: 850.0, Count: 4794
# ROAD Value: 851.0, Count: 4872
# ROAD Value: 852.0, Count: 4827
# ROAD Value: 853.0, Count: 4735
# ROAD Value: 854.0, Count: 4708
# ROAD Value: 855.0, Count: 4794
# ROAD Value: 856.0, Count: 4629
# ROAD Value: 857.0, Count: 4690
# ROAD Value: 858.0, Count: 4580
# ROAD Value: 859.0, Count: 4732
# ROAD Value: 860.0, Count: 4646
# ROAD Value: 861.0, Count: 4585
# ROAD Value: 862.0, Count: 4556
# ROAD Value: 863.0, Count: 4443
# ROAD Value: 864.0, Count: 4633
# ROAD Value: 865.0, Count: 4459
# ROAD Value: 866.0, Count: 4419
# ROAD Value: 867.0, Count: 4267
# ROAD Value: 868.0, Count: 4307
# ROAD Value: 869.0, Count: 4230
# ROAD Value: 870.0, Count: 4117
# ROAD Value: 871.0, Count: 4146
# ROAD Value: 872.0, Count: 4145
# ROAD Value: 873.0, Count: 4050
# ROAD Value: 874.0, Count: 4020
# ROAD Value: 875.0, Count: 3983
# ROAD Value: 876.0, Count: 4136
# ROAD Value: 877.0, Count: 3987
# ROAD Value: 878.0, Count: 4029
# ROAD Value: 879.0, Count: 3964
# ROAD Value: 880.0, Count: 3922
# ROAD Value: 881.0, Count: 4154
# ROAD Value: 882.0, Count: 3978
# ROAD Value: 883.0, Count: 3979
# ROAD Value: 884.0, Count: 3920
# ROAD Value: 885.0, Count: 4141
# ROAD Value: 886.0, Count: 4252
# ROAD Value: 887.0, Count: 4059
# ROAD Value: 888.0, Count: 4143
# ROAD Value: 889.0, Count: 4160
# ROAD Value: 890.0, Count: 4109
# ROAD Value: 891.0, Count: 4129
# ROAD Value: 892.0, Count: 3997
# ROAD Value: 893.0, Count: 4246
# ROAD Value: 894.0, Count: 3889
# ROAD Value: 895.0, Count: 3905
# ROAD Value: 896.0, Count: 3793
# ROAD Value: 897.0, Count: 3624
# ROAD Value: 898.0, Count: 3875
# ROAD Value: 899.0, Count: 3559
# ROAD Value: 900.0, Count: 3575
# ROAD Value: 901.0, Count: 3489
# ROAD Value: 902.0, Count: 3520
# ROAD Value: 903.0, Count: 3503
# ROAD Value: 904.0, Count: 3404
# ROAD Value: 905.0, Count: 3475
# ROAD Value: 906.0, Count: 3692
# ROAD Value: 907.0, Count: 3484
# ROAD Value: 908.0, Count: 3341
# ROAD Value: 909.0, Count: 3269
# ROAD Value: 910.0, Count: 3483
# ROAD Value: 911.0, Count: 3349
# ROAD Value: 912.0, Count: 3213
# ROAD Value: 913.0, Count: 3155
# ROAD Value: 914.0, Count: 3124
# ROAD Value: 915.0, Count: 3107
# ROAD Value: 916.0, Count: 2966
# ROAD Value: 917.0, Count: 3032
# ROAD Value: 918.0, Count: 3019
# ROAD Value: 919.0, Count: 3154
# ROAD Value: 920.0, Count: 2981
# ROAD Value: 921.0, Count: 2968
# ROAD Value: 922.0, Count: 3016
# ROAD Value: 923.0, Count: 3058
# ROAD Value: 924.0, Count: 3014
# ROAD Value: 925.0, Count: 2949
# ROAD Value: 926.0, Count: 2917
# ROAD Value: 927.0, Count: 2997
# ROAD Value: 928.0, Count: 2899
# ROAD Value: 929.0, Count: 2968
# ROAD Value: 930.0, Count: 2928
# ROAD Value: 931.0, Count: 3076
# ROAD Value: 932.0, Count: 2950
# ROAD Value: 933.0, Count: 2846
# ROAD Value: 934.0, Count: 2872
# ROAD Value: 935.0, Count: 2800
# ROAD Value: 936.0, Count: 2970
# ROAD Value: 937.0, Count: 2821
# ROAD Value: 938.0, Count: 2796
# ROAD Value: 939.0, Count: 2884
# ROAD Value: 940.0, Count: 2893
# ROAD Value: 941.0, Count: 2885
# ROAD Value: 942.0, Count: 2809
# ROAD Value: 943.0, Count: 2828
# ROAD Value: 944.0, Count: 2946
# ROAD Value: 945.0, Count: 2770
# ROAD Value: 946.0, Count: 2809
# ROAD Value: 947.0, Count: 2731
# ROAD Value: 948.0, Count: 2870
# ROAD Value: 949.0, Count: 2813
# ROAD Value: 950.0, Count: 2712
# ROAD Value: 951.0, Count: 2784
# ROAD Value: 952.0, Count: 2707
# ROAD Value: 953.0, Count: 2897
# ROAD Value: 954.0, Count: 2785
# ROAD Value: 955.0, Count: 2722
# ROAD Value: 956.0, Count: 2821
# ROAD Value: 957.0, Count: 2821
# ROAD Value: 958.0, Count: 2793
# ROAD Value: 959.0, Count: 2748
# ROAD Value: 960.0, Count: 2682
# ROAD Value: 961.0, Count: 2842
# ROAD Value: 962.0, Count: 2653
# ROAD Value: 963.0, Count: 2636
# ROAD Value: 964.0, Count: 2612
# ROAD Value: 965.0, Count: 2721
# ROAD Value: 966.0, Count: 2634
# ROAD Value: 967.0, Count: 2600
# ROAD Value: 968.0, Count: 2608
# ROAD Value: 969.0, Count: 2552
# ROAD Value: 970.0, Count: 2688
# ROAD Value: 971.0, Count: 2586
# ROAD Value: 972.0, Count: 2559
# ROAD Value: 973.0, Count: 2533
# ROAD Value: 974.0, Count: 2655
# ROAD Value: 975.0, Count: 2519
# ROAD Value: 976.0, Count: 2494
# ROAD Value: 977.0, Count: 2481
# ROAD Value: 978.0, Count: 2557
# ROAD Value: 979.0, Count: 2503
# ROAD Value: 980.0, Count: 2451
# ROAD Value: 981.0, Count: 2419
# ROAD Value: 982.0, Count: 2533
# ROAD Value: 983.0, Count: 2379
# ROAD Value: 984.0, Count: 2387
# ROAD Value: 985.0, Count: 2388
# ROAD Value: 986.0, Count: 2351
# ROAD Value: 987.0, Count: 2510
# ROAD Value: 988.0, Count: 2316
# ROAD Value: 989.0, Count: 2350
# ROAD Value: 990.0, Count: 2323
# ROAD Value: 991.0, Count: 2433
# ROAD Value: 992.0, Count: 2345
# ROAD Value: 993.0, Count: 2284
# ROAD Value: 994.0, Count: 2299
# ROAD Value: 995.0, Count: 2357
# ROAD Value: 996.0, Count: 2227
# ROAD Value: 997.0, Count: 2256
# ROAD Value: 998.0, Count: 2210
# ROAD Value: 999.0, Count: 2340
# ROAD Value: 1000.0, Count: 2215
# ROAD Value: 1001.0, Count: 2188
# ROAD Value: 1002.0, Count: 2215
# ROAD Value: 1003.0, Count: 2252
# ROAD Value: 1004.0, Count: 2280
# ROAD Value: 1005.0, Count: 2220
# ROAD Value: 1006.0, Count: 2223
# ROAD Value: 1007.0, Count: 2247
# ROAD Value: 1008.0, Count: 2330
# ROAD Value: 1009.0, Count: 2261
# ROAD Value: 1010.0, Count: 2234
# ROAD Value: 1011.0, Count: 2235
# ROAD Value: 1012.0, Count: 2365
# ROAD Value: 1013.0, Count: 2248
# ROAD Value: 1014.0, Count: 2244
# ROAD Value: 1015.0, Count: 2209
# ROAD Value: 1016.0, Count: 2361
# ROAD Value: 1017.0, Count: 2277
# ROAD Value: 1018.0, Count: 2274
# ROAD Value: 1019.0, Count: 2222
# ROAD Value: 1020.0, Count: 2324
# ROAD Value: 1021.0, Count: 2254
# ROAD Value: 1022.0, Count: 2187
# ROAD Value: 1023.0, Count: 2052
# ROAD Value: 1024.0, Count: 1872
# ROAD Value: 1025.0, Count: 2022
# ROAD Value: 1026.0, Count: 1919
# ROAD Value: 1027.0, Count: 1887
# ROAD Value: 1028.0, Count: 1899
# ROAD Value: 1029.0, Count: 2034
# ROAD Value: 1030.0, Count: 1944
# ROAD Value: 1031.0, Count: 1906
# ROAD Value: 1032.0, Count: 1906
# ROAD Value: 1033.0, Count: 2000
# ROAD Value: 1034.0, Count: 1876
# ROAD Value: 1035.0, Count: 1883
# ROAD Value: 1036.0, Count: 1844
# ROAD Value: 1037.0, Count: 1969
# ROAD Value: 1038.0, Count: 1898
# ROAD Value: 1039.0, Count: 1848
# ROAD Value: 1040.0, Count: 1874
# ROAD Value: 1041.0, Count: 1841
# ROAD Value: 1042.0, Count: 1995
# ROAD Value: 1043.0, Count: 1834
# ROAD Value: 1044.0, Count: 1819
# ROAD Value: 1045.0, Count: 1840
# ROAD Value: 1046.0, Count: 1985
# ROAD Value: 1047.0, Count: 1917
# ROAD Value: 1048.0, Count: 1874
# ROAD Value: 1049.0, Count: 1873
# ROAD Value: 1050.0, Count: 1999
# ROAD Value: 1051.0, Count: 1865
# ROAD Value: 1052.0, Count: 1839
# ROAD Value: 1053.0, Count: 1812
# ROAD Value: 1054.0, Count: 1957
# ROAD Value: 1055.0, Count: 1947
# ROAD Value: 1056.0, Count: 1881
# ROAD Value: 1057.0, Count: 1881
# ROAD Value: 1058.0, Count: 1841
# ROAD Value: 1059.0, Count: 1966
# ROAD Value: 1060.0, Count: 1873
# ROAD Value: 1061.0, Count: 1825
# ROAD Value: 1062.0, Count: 1806
# ROAD Value: 1063.0, Count: 1931
# ROAD Value: 1064.0, Count: 1773
# ROAD Value: 1065.0, Count: 1788
# ROAD Value: 1066.0, Count: 1752
# ROAD Value: 1067.0, Count: 1890
# ROAD Value: 1068.0, Count: 1768
# ROAD Value: 1069.0, Count: 1729
# ROAD Value: 1070.0, Count: 1708
# ROAD Value: 1071.0, Count: 1927
# ROAD Value: 1072.0, Count: 1851
# ROAD Value: 1073.0, Count: 1805
# ROAD Value: 1074.0, Count: 1787
# ROAD Value: 1075.0, Count: 1855
# ROAD Value: 1076.0, Count: 1777
# ROAD Value: 1077.0, Count: 1748
# ROAD Value: 1078.0, Count: 1757
# ROAD Value: 1079.0, Count: 1727
# ROAD Value: 1080.0, Count: 1843
# ROAD Value: 1081.0, Count: 1729
# ROAD Value: 1082.0, Count: 1698
# ROAD Value: 1083.0, Count: 1706
# ROAD Value: 1084.0, Count: 1790
# ROAD Value: 1085.0, Count: 1699
# ROAD Value: 1086.0, Count: 1662
# ROAD Value: 1087.0, Count: 1659
# ROAD Value: 1088.0, Count: 1737
# ROAD Value: 1089.0, Count: 1659
# ROAD Value: 1090.0, Count: 1643
# ROAD Value: 1091.0, Count: 1628
# ROAD Value: 1092.0, Count: 1682
# ROAD Value: 1093.0, Count: 1629
# ROAD Value: 1094.0, Count: 1596
# ROAD Value: 1095.0, Count: 1555
# ROAD Value: 1096.0, Count: 1558
# ROAD Value: 1097.0, Count: 1653
# ROAD Value: 1098.0, Count: 1554
# ROAD Value: 1099.0, Count: 1524
# ROAD Value: 1100.0, Count: 1475
# ROAD Value: 1101.0, Count: 1565
# ROAD Value: 1102.0, Count: 1462
# ROAD Value: 1103.0, Count: 1445
# ROAD Value: 1104.0, Count: 1402
# ROAD Value: 1105.0, Count: 1490
# ROAD Value: 1106.0, Count: 1413
# ROAD Value: 1107.0, Count: 1369
# ROAD Value: 1108.0, Count: 1376
# ROAD Value: 1109.0, Count: 1390
# ROAD Value: 1110.0, Count: 1275
# ROAD Value: 1111.0, Count: 1232
# ROAD Value: 1112.0, Count: 1164
# ROAD Value: 1113.0, Count: 1151
# ROAD Value: 1114.0, Count: 1132
# ROAD Value: 1115.0, Count: 1057
# ROAD Value: 1116.0, Count: 1032
# ROAD Value: 1117.0, Count: 993
# ROAD Value: 1118.0, Count: 1018
# ROAD Value: 1119.0, Count: 1002
# ROAD Value: 1120.0, Count: 986
# ROAD Value: 1121.0, Count: 976
# ROAD Value: 1122.0, Count: 971
# ROAD Value: 1123.0, Count: 950
# ROAD Value: 1124.0, Count: 937
# ROAD Value: 1125.0, Count: 911
# ROAD Value: 1126.0, Count: 915
# ROAD Value: 1127.0, Count: 904
# ROAD Value: 1128.0, Count: 892
# ROAD Value: 1129.0, Count: 875
# ROAD Value: 1130.0, Count: 862
# ROAD Value: 1131.0, Count: 879
# ROAD Value: 1132.0, Count: 841
# ROAD Value: 1133.0, Count: 846
# ROAD Value: 1134.0, Count: 838
# ROAD Value: 1135.0, Count: 814
# ROAD Value: 1136.0, Count: 824
# ROAD Value: 1137.0, Count: 806
# ROAD Value: 1138.0, Count: 803
# ROAD Value: 1139.0, Count: 802
# ROAD Value: 1140.0, Count: 790
# ROAD Value: 1141.0, Count: 780
# ROAD Value: 1142.0, Count: 779
# ROAD Value: 1143.0, Count: 770
# ROAD Value: 1144.0, Count: 765
# ROAD Value: 1145.0, Count: 736
# ROAD Value: 1146.0, Count: 746
# ROAD Value: 1147.0, Count: 736
# ROAD Value: 1148.0, Count: 714
# ROAD Value: 1149.0, Count: 720
# ROAD Value: 1150.0, Count: 704
# ROAD Value: 1151.0, Count: 698
# ROAD Value: 1152.0, Count: 692
# ROAD Value: 1153.0, Count: 678
# ROAD Value: 1154.0, Count: 673
# ROAD Value: 1155.0, Count: 662
# ROAD Value: 1156.0, Count: 647
# ROAD Value: 1157.0, Count: 653
# ROAD Value: 1158.0, Count: 628
# ROAD Value: 1159.0, Count: 615
# ROAD Value: 1160.0, Count: 613
# ROAD Value: 1161.0, Count: 606
# ROAD Value: 1162.0, Count: 592
# ROAD Value: 1163.0, Count: 583
# ROAD Value: 1164.0, Count: 562
# ROAD Value: 1165.0, Count: 560
# ROAD Value: 1166.0, Count: 566
# ROAD Value: 1167.0, Count: 554
# ROAD Value: 1168.0, Count: 557
# ROAD Value: 1169.0, Count: 549
# ROAD Value: 1170.0, Count: 542
# ROAD Value: 1171.0, Count: 549
# ROAD Value: 1172.0, Count: 564
# ROAD Value: 1173.0, Count: 615
# ROAD Value: 1174.0, Count: 582
# ROAD Value: 1175.0, Count: 554
# ROAD Value: 1176.0, Count: 585
# ROAD Value: 1177.0, Count: 531
# ROAD Value: 1178.0, Count: 542
# ROAD Value: 1179.0, Count: 532
# ROAD Value: 1180.0, Count: 543
# ROAD Value: 1181.0, Count: 539
# ROAD Value: 1182.0, Count: 526
# ROAD Value: 1183.0, Count: 547
# ROAD Value: 1184.0, Count: 533
# ROAD Value: 1185.0, Count: 546
# ROAD Value: 1186.0, Count: 531
# ROAD Value: 1187.0, Count: 549
# ROAD Value: 1188.0, Count: 544
# ROAD Value: 1189.0, Count: 553
# ROAD Value: 1190.0, Count: 562
# ROAD Value: 1191.0, Count: 556
# ROAD Value: 1192.0, Count: 560
# ROAD Value: 1193.0, Count: 559
# ROAD Value: 1194.0, Count: 544
# ROAD Value: 1195.0, Count: 556
# ROAD Value: 1196.0, Count: 543
# ROAD Value: 1197.0, Count: 548
# ROAD Value: 1198.0, Count: 555
# ROAD Value: 1199.0, Count: 548
# ROAD Value: 1200.0, Count: 562
# ROAD Value: 1201.0, Count: 556
# ROAD Value: 1202.0, Count: 558
# ROAD Value: 1203.0, Count: 574
# ROAD Value: 1204.0, Count: 561
# ROAD Value: 1205.0, Count: 567
# ROAD Value: 1206.0, Count: 549
# ROAD Value: 1207.0, Count: 554
# ROAD Value: 1208.0, Count: 550
# ROAD Value: 1209.0, Count: 539
# ROAD Value: 1210.0, Count: 562
# ROAD Value: 1211.0, Count: 563
# ROAD Value: 1212.0, Count: 558
# ROAD Value: 1213.0, Count: 579
# ROAD Value: 1214.0, Count: 575
# ROAD Value: 1215.0, Count: 566
# ROAD Value: 1216.0, Count: 561
# ROAD Value: 1217.0, Count: 581
# ROAD Value: 1218.0, Count: 573
# ROAD Value: 1219.0, Count: 587
# ROAD Value: 1220.0, Count: 577
# ROAD Value: 1221.0, Count: 586
# ROAD Value: 1222.0, Count: 601
# ROAD Value: 1223.0, Count: 604
# ROAD Value: 1224.0, Count: 608
# ROAD Value: 1225.0, Count: 621
# ROAD Value: 1226.0, Count: 617
# ROAD Value: 1227.0, Count: 627
# ROAD Value: 1228.0, Count: 626
# ROAD Value: 1229.0, Count: 622
# ROAD Value: 1230.0, Count: 643
# ROAD Value: 1231.0, Count: 634
# ROAD Value: 1232.0, Count: 642
# ROAD Value: 1233.0, Count: 659
# ROAD Value: 1234.0, Count: 652
# ROAD Value: 1235.0, Count: 668
# ROAD Value: 1236.0, Count: 666
# ROAD Value: 1237.0, Count: 676
# ROAD Value: 1238.0, Count: 676
# ROAD Value: 1239.0, Count: 672
# ROAD Value: 1240.0, Count: 686
# ROAD Value: 1241.0, Count: 683
# ROAD Value: 1242.0, Count: 694
# ROAD Value: 1243.0, Count: 713
# ROAD Value: 1244.0, Count: 742
# ROAD Value: 1245.0, Count: 762
# ROAD Value: 1246.0, Count: 728
# ROAD Value: 1247.0, Count: 726
# ROAD Value: 1248.0, Count: 726
# ROAD Value: 1249.0, Count: 726
# ROAD Value: 1250.0, Count: 740
# ROAD Value: 1251.0, Count: 716
# ROAD Value: 1252.0, Count: 731
# ROAD Value: 1253.0, Count: 726
# ROAD Value: 1254.0, Count: 719
# ROAD Value: 1255.0, Count: 733
# ROAD Value: 1256.0, Count: 728
# ROAD Value: 1257.0, Count: 730
# ROAD Value: 1258.0, Count: 733
# ROAD Value: 1259.0, Count: 721
# ROAD Value: 1260.0, Count: 749
# ROAD Value: 1261.0, Count: 731
# ROAD Value: 1262.0, Count: 738
# ROAD Value: 1263.0, Count: 740
# ROAD Value: 1264.0, Count: 728
# ROAD Value: 1265.0, Count: 738
# ROAD Value: 1266.0, Count: 736
# ROAD Value: 1267.0, Count: 738
# ROAD Value: 1268.0, Count: 730
# ROAD Value: 1269.0, Count: 723
# ROAD Value: 1270.0, Count: 744
# ROAD Value: 1271.0, Count: 726
# ROAD Value: 1272.0, Count: 740
# ROAD Value: 1273.0, Count: 729
# ROAD Value: 1274.0, Count: 732
# ROAD Value: 1275.0, Count: 733
# ROAD Value: 1276.0, Count: 724
# ROAD Value: 1277.0, Count: 727
# ROAD Value: 1278.0, Count: 719
# ROAD Value: 1279.0, Count: 723
# ROAD Value: 1280.0, Count: 720
# ROAD Value: 1281.0, Count: 716
# ROAD Value: 1282.0, Count: 725
# ROAD Value: 1283.0, Count: 736
# ROAD Value: 1284.0, Count: 733
# ROAD Value: 1285.0, Count: 740
# ROAD Value: 1286.0, Count: 746
# ROAD Value: 1287.0, Count: 745
# ROAD Value: 1288.0, Count: 755
# ROAD Value: 1289.0, Count: 747
# ROAD Value: 1290.0, Count: 766
# ROAD Value: 1291.0, Count: 760
# ROAD Value: 1292.0, Count: 752
# ROAD Value: 1293.0, Count: 758
# ROAD Value: 1294.0, Count: 761
# ROAD Value: 1295.0, Count: 763
# ROAD Value: 1296.0, Count: 781
# ROAD Value: 1297.0, Count: 780
# ROAD Value: 1298.0, Count: 796
# ROAD Value: 1299.0, Count: 805
# ROAD Value: 1300.0, Count: 805
# ROAD Value: 1301.0, Count: 822
# ROAD Value: 1302.0, Count: 827
# ROAD Value: 1303.0, Count: 833
# ROAD Value: 1304.0, Count: 841
# ROAD Value: 1305.0, Count: 850
# ROAD Value: 1306.0, Count: 848
# ROAD Value: 1307.0, Count: 866
# ROAD Value: 1308.0, Count: 867
# ROAD Value: 1309.0, Count: 880
# ROAD Value: 1310.0, Count: 874
# ROAD Value: 1311.0, Count: 883
# ROAD Value: 1312.0, Count: 894
# ROAD Value: 1313.0, Count: 881
# ROAD Value: 1314.0, Count: 904
# ROAD Value: 1315.0, Count: 917
# ROAD Value: 1316.0, Count: 959
# ROAD Value: 1317.0, Count: 967
# ROAD Value: 1318.0, Count: 985
# ROAD Value: 1319.0, Count: 1004
# ROAD Value: 1320.0, Count: 1019
# ROAD Value: 1321.0, Count: 1018
# ROAD Value: 1322.0, Count: 1011
# ROAD Value: 1323.0, Count: 1001
# ROAD Value: 1324.0, Count: 1006
# ROAD Value: 1325.0, Count: 997
# ROAD Value: 1326.0, Count: 993
# ROAD Value: 1327.0, Count: 987
# ROAD Value: 1328.0, Count: 975
# ROAD Value: 1329.0, Count: 960
# ROAD Value: 1330.0, Count: 946
# ROAD Value: 1331.0, Count: 978
# ROAD Value: 1332.0, Count: 948
# ROAD Value: 1333.0, Count: 985
# ROAD Value: 1334.0, Count: 1014
# ROAD Value: 1335.0, Count: 957
# ROAD Value: 1336.0, Count: 968
# ROAD Value: 1337.0, Count: 954
# ROAD Value: 1338.0, Count: 963
# ROAD Value: 1339.0, Count: 935
# ROAD Value: 1340.0, Count: 915
# ROAD Value: 1341.0, Count: 912
# ROAD Value: 1342.0, Count: 929
# ROAD Value: 1343.0, Count: 878
# ROAD Value: 1344.0, Count: 884
# ROAD Value: 1345.0, Count: 872
# ROAD Value: 1346.0, Count: 850
# ROAD Value: 1347.0, Count: 879
# ROAD Value: 1348.0, Count: 828
# ROAD Value: 1349.0, Count: 833
# ROAD Value: 1350.0, Count: 741
# ROAD Value: 1351.0, Count: 709
# ROAD Value: 1352.0, Count: 699
# ROAD Value: 1353.0, Count: 688
# ROAD Value: 1354.0, Count: 676
# ROAD Value: 1355.0, Count: 696
# ROAD Value: 1356.0, Count: 668
# ROAD Value: 1357.0, Count: 658
# ROAD Value: 1358.0, Count: 647
# ROAD Value: 1359.0, Count: 651
# ROAD Value: 1360.0, Count: 623
# ROAD Value: 1361.0, Count: 624
# ROAD Value: 1362.0, Count: 613
# ROAD Value: 1363.0, Count: 602
# ROAD Value: 1364.0, Count: 622
# ROAD Value: 1365.0, Count: 582
# ROAD Value: 1366.0, Count: 595
# ROAD Value: 1367.0, Count: 566
# ROAD Value: 1368.0, Count: 593
# ROAD Value: 1369.0, Count: 563
# ROAD Value: 1370.0, Count: 535
# ROAD Value: 1371.0, Count: 554
# ROAD Value: 1372.0, Count: 525
# ROAD Value: 1373.0, Count: 517
# ROAD Value: 1374.0, Count: 486
# ROAD Value: 1375.0, Count: 459
# ROAD Value: 1376.0, Count: 486
# ROAD Value: 1377.0, Count: 432
# ROAD Value: 1378.0, Count: 462
# ROAD Value: 1379.0, Count: 429
# ROAD Value: 1380.0, Count: 450
# ROAD Value: 1381.0, Count: 440
# ROAD Value: 1382.0, Count: 420
# ROAD Value: 1383.0, Count: 444
# ROAD Value: 1384.0, Count: 411
# ROAD Value: 1385.0, Count: 432
# ROAD Value: 1386.0, Count: 427
# ROAD Value: 1387.0, Count: 399
# ROAD Value: 1388.0, Count: 426
# ROAD Value: 1389.0, Count: 400
# ROAD Value: 1390.0, Count: 417
# ROAD Value: 1391.0, Count: 395
# ROAD Value: 1392.0, Count: 384
# ROAD Value: 1393.0, Count: 415
# ROAD Value: 1394.0, Count: 385
# ROAD Value: 1395.0, Count: 392
# ROAD Value: 1396.0, Count: 368
# ROAD Value: 1397.0, Count: 361
# ROAD Value: 1398.0, Count: 368
# ROAD Value: 1399.0, Count: 354
# ROAD Value: 1400.0, Count: 357
# ROAD Value: 1401.0, Count: 339
# ROAD Value: 1402.0, Count: 353
# ROAD Value: 1403.0, Count: 347
# ROAD Value: 1404.0, Count: 333
# ROAD Value: 1405.0, Count: 338
# ROAD Value: 1406.0, Count: 338
# ROAD Value: 1407.0, Count: 329
# ROAD Value: 1408.0, Count: 325
# ROAD Value: 1409.0, Count: 319
# ROAD Value: 1410.0, Count: 329
# ROAD Value: 1411.0, Count: 334
# ROAD Value: 1412.0, Count: 332
# ROAD Value: 1413.0, Count: 330
# ROAD Value: 1414.0, Count: 335
# ROAD Value: 1415.0, Count: 341
# ROAD Value: 1416.0, Count: 340
# ROAD Value: 1417.0, Count: 348
# ROAD Value: 1418.0, Count: 341
# ROAD Value: 1419.0, Count: 359
# ROAD Value: 1420.0, Count: 348
# ROAD Value: 1421.0, Count: 351
# ROAD Value: 1422.0, Count: 348
# ROAD Value: 1423.0, Count: 366
# ROAD Value: 1424.0, Count: 365
# ROAD Value: 1425.0, Count: 360
# ROAD Value: 1426.0, Count: 360
# ROAD Value: 1427.0, Count: 368
# ROAD Value: 1428.0, Count: 373
# ROAD Value: 1429.0, Count: 370
# ROAD Value: 1430.0, Count: 375
# ROAD Value: 1431.0, Count: 376
# ROAD Value: 1432.0, Count: 382
# ROAD Value: 1433.0, Count: 382
# ROAD Value: 1434.0, Count: 372
# ROAD Value: 1435.0, Count: 376
# ROAD Value: 1436.0, Count: 391
# ROAD Value: 1437.0, Count: 378
# ROAD Value: 1438.0, Count: 378
# ROAD Value: 1439.0, Count: 374
# ROAD Value: 1440.0, Count: 384
# ROAD Value: 1441.0, Count: 382
# ROAD Value: 1442.0, Count: 380
# ROAD Value: 1443.0, Count: 381
# ROAD Value: 1444.0, Count: 383
# ROAD Value: 1445.0, Count: 380
# ROAD Value: 1446.0, Count: 382
# ROAD Value: 1447.0, Count: 373
# ROAD Value: 1448.0, Count: 388
# ROAD Value: 1449.0, Count: 380
# ROAD Value: 1450.0, Count: 380
# ROAD Value: 1451.0, Count: 377
# ROAD Value: 1452.0, Count: 372
# ROAD Value: 1453.0, Count: 386
# ROAD Value: 1454.0, Count: 385
# ROAD Value: 1455.0, Count: 375
# ROAD Value: 1456.0, Count: 379
# ROAD Value: 1457.0, Count: 387
# ROAD Value: 1458.0, Count: 378
# ROAD Value: 1459.0, Count: 376
# ROAD Value: 1460.0, Count: 376
# ROAD Value: 1461.0, Count: 390
# ROAD Value: 1462.0, Count: 375
# ROAD Value: 1463.0, Count: 377
# ROAD Value: 1464.0, Count: 375
# ROAD Value: 1465.0, Count: 382
# ROAD Value: 1466.0, Count: 384
# ROAD Value: 1467.0, Count: 379
# ROAD Value: 1468.0, Count: 374
# ROAD Value: 1469.0, Count: 381
# ROAD Value: 1470.0, Count: 381
# ROAD Value: 1471.0, Count: 377
# ROAD Value: 1472.0, Count: 378
# ROAD Value: 1473.0, Count: 373
# ROAD Value: 1474.0, Count: 390
# ROAD Value: 1475.0, Count: 371
# ROAD Value: 1476.0, Count: 372
# ROAD Value: 1477.0, Count: 371
# ROAD Value: 1478.0, Count: 386
# ROAD Value: 1479.0, Count: 385
# ROAD Value: 1480.0, Count: 376
# ROAD Value: 1481.0, Count: 375
# ROAD Value: 1482.0, Count: 384
# ROAD Value: 1483.0, Count: 377
# ROAD Value: 1484.0, Count: 372
# ROAD Value: 1485.0, Count: 381
# ROAD Value: 1486.0, Count: 378
# ROAD Value: 1487.0, Count: 385
# ROAD Value: 1488.0, Count: 375
# ROAD Value: 1489.0, Count: 371
# ROAD Value: 1490.0, Count: 374
# ROAD Value: 1491.0, Count: 386
# ROAD Value: 1492.0, Count: 376
# ROAD Value: 1493.0, Count: 375
# ROAD Value: 1494.0, Count: 372
# ROAD Value: 1495.0, Count: 385
# ROAD Value: 1496.0, Count: 377
# ROAD Value: 1497.0, Count: 376
# ROAD Value: 1498.0, Count: 375
# ROAD Value: 1499.0, Count: 380
# ROAD Value: 1500.0, Count: 378
# ROAD Value: 1501.0, Count: 376
# ROAD Value: 1502.0, Count: 367
# ROAD Value: 1503.0, Count: 389
# ROAD Value: 1504.0, Count: 380
# ROAD Value: 1505.0, Count: 377
# ROAD Value: 1506.0, Count: 365
# ROAD Value: 1507.0, Count: 369
# ROAD Value: 1508.0, Count: 389
# ROAD Value: 1509.0, Count: 375
# ...
# PORTS Value: 1141.0, Count: 14983
# PORTS Value: 1142.0, Count: 13278
# PORTS Value: 1143.0, Count: 12599
# PORTS Value: 1144.0, Count: 11491
# PORTS Value: 1145.0, Count: 10666
# PORTS Value: 1146.0, Count: 6422
# PORTS Value: 1147.0, Count: 15082
# PORTS Value: 1148.0, Count: 8400
# PORTS Value: 1149.0, Count: 4144
# PORTS Value: 1150.0, Count: 7929
# PORTS Value: 1151.0, Count: 13651
# PORTS Value: 1152.0, Count: 14632
# PORTS Value: 1153.0, Count: 7770
# PORTS Value: 1154.0, Count: 10979
# PORTS Value: 1155.0, Count: 13467
# PORTS Value: 1156.0, Count: 11138
# PORTS Value: 1157.0, Count: 9104
# PORTS Value: 1158.0, Count: 10010
# PORTS Value: 1159.0, Count: 10250
# PORTS Value: 1160.0, Count: 8375
# PORTS Value: 1161.0, Count: 9841
# PORTS Value: 1162.0, Count: 5868
# PORTS Value: 1163.0, Count: 13473
# PORTS Value: 1164.0, Count: 10121
# PORTS Value: 1165.0, Count: 11019
# PORTS Value: 1166.0, Count: 7876
# PORTS Value: 1167.0, Count: 12305
# PORTS Value: 1168.0, Count: 8119
# PORTS Value: 1169.0, Count: 16203
# PORTS Value: 1170.0, Count: 8730
# PORTS Value: 1171.0, Count: 7848
# PORTS Value: 1172.0, Count: 5532
# PORTS Value: 1173.0, Count: 9431
# PORTS Value: 1174.0, Count: 11951
# PORTS Value: 1175.0, Count: 8761
# PORTS Value: 1176.0, Count: 9897
# PORTS Value: 1177.0, Count: 10606
# PORTS Value: 1178.0, Count: 8995
# PORTS Value: 1179.0, Count: 14540
# PORTS Value: 1180.0, Count: 8678
# PORTS Value: 1181.0, Count: 13035
# PORTS Value: 1182.0, Count: 8839
# PORTS Value: 1183.0, Count: 7636
# PORTS Value: 1184.0, Count: 10019
# PORTS Value: 1185.0, Count: 5923
# PORTS Value: 1186.0, Count: 10289
# PORTS Value: 1187.0, Count: 14431
# PORTS Value: 1188.0, Count: 10461
# PORTS Value: 1189.0, Count: 8264
# PORTS Value: 1190.0, Count: 15928
# PORTS Value: 1191.0, Count: 11227
# PORTS Value: 1192.0, Count: 15460
# PORTS Value: 1193.0, Count: 17730
# PORTS Value: 1194.0, Count: 9030
# PORTS Value: 1195.0, Count: 8104
# PORTS Value: 1196.0, Count: 13145
# PORTS Value: 1197.0, Count: 11813
# PORTS Value: 1198.0, Count: 12150
# PORTS Value: 1199.0, Count: 11588
# PORTS Value: 1200.0, Count: 10928
# PORTS Value: 1201.0, Count: 14301
# PORTS Value: 1202.0, Count: 12807
# PORTS Value: 1203.0, Count: 13848
# PORTS Value: 1204.0, Count: 12625
# PORTS Value: 1205.0, Count: 19508
# PORTS Value: 1206.0, Count: 17256
# PORTS Value: 1207.0, Count: 14565
# PORTS Value: 1208.0, Count: 9476
# PORTS Value: 1209.0, Count: 6310
# PORTS Value: 1210.0, Count: 5958
# PORTS Value: 1211.0, Count: 13736
# PORTS Value: 1212.0, Count: 15921
# PORTS Value: 1213.0, Count: 11479
# PORTS Value: 1214.0, Count: 13762
# PORTS Value: 1215.0, Count: 12054
# PORTS Value: 1216.0, Count: 12053
# PORTS Value: 1217.0, Count: 17405
# PORTS Value: 1218.0, Count: 16596
# PORTS Value: 1219.0, Count: 7738
# PORTS Value: 1220.0, Count: 12779
# PORTS Value: 1221.0, Count: 15431
# PORTS Value: 1222.0, Count: 8969
# PORTS Value: 1223.0, Count: 8119
# PORTS Value: 1224.0, Count: 14597
# PORTS Value: 1225.0, Count: 11322
# PORTS Value: 1226.0, Count: 17472
# PORTS Value: 1227.0, Count: 16618
# PORTS Value: 1228.0, Count: 11912
# PORTS Value: 1229.0, Count: 10893
# PORTS Value: 1230.0, Count: 12830
# PORTS Value: 1231.0, Count: 9719
# PORTS Value: 1232.0, Count: 8872
# PORTS Value: 1233.0, Count: 20173
# PORTS Value: 1234.0, Count: 17826
# PORTS Value: 1235.0, Count: 5989
# PORTS Value: 1236.0, Count: 14060
# PORTS Value: 1237.0, Count: 8261
# PORTS Value: 1238.0, Count: 17776
# PORTS Value: 1239.0, Count: 19238
# PORTS Value: 1240.0, Count: 16688
# PORTS Value: 1241.0, Count: 13201
# PORTS Value: 1242.0, Count: 8424
# PORTS Value: 1243.0, Count: 17584
# PORTS Value: 1244.0, Count: 8774
# PORTS Value: 1245.0, Count: 11717
# PORTS Value: 1246.0, Count: 15992
# PORTS Value: 1247.0, Count: 7406
# PORTS Value: 1248.0, Count: 13952
# PORTS Value: 1249.0, Count: 13820
# PORTS Value: 1250.0, Count: 9104
# PORTS Value: 1251.0, Count: 11580
# PORTS Value: 1252.0, Count: 23196
# PORTS Value: 1253.0, Count: 14794
# PORTS Value: 1254.0, Count: 13398
# PORTS Value: 1255.0, Count: 13069
# PORTS Value: 1256.0, Count: 10406
# PORTS Value: 1257.0, Count: 13847
# PORTS Value: 1258.0, Count: 13573
# PORTS Value: 1259.0, Count: 8167
# PORTS Value: 1260.0, Count: 8643
# PORTS Value: 1261.0, Count: 12783
# PORTS Value: 1262.0, Count: 9357
# PORTS Value: 1263.0, Count: 12053
# PORTS Value: 1264.0, Count: 14066
# PORTS Value: 1265.0, Count: 15598
# PORTS Value: 1266.0, Count: 14817
# PORTS Value: 1267.0, Count: 8340
# PORTS Value: 1268.0, Count: 12133
# PORTS Value: 1269.0, Count: 6043
# PORTS Value: 1270.0, Count: 12783
# PORTS Value: 1271.0, Count: 9226
# PORTS Value: 1272.0, Count: 7633
# PORTS Value: 1273.0, Count: 9675
# PORTS Value: 1274.0, Count: 8823
# PORTS Value: 1275.0, Count: 14304
# PORTS Value: 1276.0, Count: 11325
# PORTS Value: 1277.0, Count: 15848
# PORTS Value: 1278.0, Count: 5306
# PORTS Value: 1279.0, Count: 8650
# PORTS Value: 1280.0, Count: 12750
# PORTS Value: 1281.0, Count: 5740
# PORTS Value: 1282.0, Count: 6249
# PORTS Value: 1283.0, Count: 10499
# PORTS Value: 1284.0, Count: 8959
# PORTS Value: 1285.0, Count: 9444
# PORTS Value: 1286.0, Count: 7207
# PORTS Value: 1287.0, Count: 6907
# PORTS Value: 1288.0, Count: 5202
# PORTS Value: 1289.0, Count: 15004
# PORTS Value: 1290.0, Count: 9976
# PORTS Value: 1291.0, Count: 13266
# PORTS Value: 1292.0, Count: 5612
# PORTS Value: 1293.0, Count: 4119
# PORTS Value: 1294.0, Count: 20898
# PORTS Value: 1295.0, Count: 9189
# PORTS Value: 1296.0, Count: 4668
# PORTS Value: 1297.0, Count: 4323
# PORTS Value: 1298.0, Count: 3335
# PORTS Value: 1299.0, Count: 8501
# PORTS Value: 1300.0, Count: 11264
# PORTS Value: 1301.0, Count: 8606
# PORTS Value: 1302.0, Count: 4840
# PORTS Value: 1303.0, Count: 5503
# PORTS Value: 1304.0, Count: 11442
# PORTS Value: 1305.0, Count: 11921
# PORTS Value: 1306.0, Count: 5256
# PORTS Value: 1307.0, Count: 5042
# PORTS Value: 1308.0, Count: 11195
# PORTS Value: 1309.0, Count: 5370
# PORTS Value: 1310.0, Count: 6679
# PORTS Value: 1311.0, Count: 5517
# PORTS Value: 1312.0, Count: 8779
# PORTS Value: 1313.0, Count: 10458
# PORTS Value: 1314.0, Count: 3673
# PORTS Value: 1315.0, Count: 1121
# PORTS Value: 1316.0, Count: 6188
# PORTS Value: 1317.0, Count: 13398
# PORTS Value: 1318.0, Count: 6187
# PORTS Value: 1319.0, Count: 10937
# PORTS Value: 1320.0, Count: 2875
# PORTS Value: 1321.0, Count: 8786
# PORTS Value: 1322.0, Count: 7093
# PORTS Value: 1323.0, Count: 3963
# PORTS Value: 1324.0, Count: 10069
# PORTS Value: 1325.0, Count: 3741
# PORTS Value: 1326.0, Count: 4957
# PORTS Value: 1327.0, Count: 3519
# PORTS Value: 1328.0, Count: 8610
# PORTS Value: 1329.0, Count: 2450
# PORTS Value: 1330.0, Count: 5964
# PORTS Value: 1331.0, Count: 6290
# PORTS Value: 1332.0, Count: 4768
# PORTS Value: 1333.0, Count: 6316
# PORTS Value: 1334.0, Count: 5073
# PORTS Value: 1335.0, Count: 6750
# PORTS Value: 1336.0, Count: 4351
# PORTS Value: 1337.0, Count: 6090
# PORTS Value: 1338.0, Count: 4566
# PORTS Value: 1339.0, Count: 3678
# PORTS Value: 1340.0, Count: 4422
# PORTS Value: 1341.0, Count: 4132
# PORTS Value: 1342.0, Count: 7300
# PORTS Value: 1343.0, Count: 3545
# PORTS Value: 1344.0, Count: 3771
# PORTS Value: 1345.0, Count: 2777
# PORTS Value: 1346.0, Count: 3751
# PORTS Value: 1347.0, Count: 7283
# PORTS Value: 1348.0, Count: 1770
# PORTS Value: 1349.0, Count: 3906
# PORTS Value: 1350.0, Count: 6780
# PORTS Value: 1351.0, Count: 3300
# PORTS Value: 1352.0, Count: 5289
# PORTS Value: 1353.0, Count: 2237
# PORTS Value: 1354.0, Count: 4786
# PORTS Value: 1355.0, Count: 4575
# PORTS Value: 1356.0, Count: 2861
# PORTS Value: 1357.0, Count: 1137
# PORTS Value: 1358.0, Count: 5898
# PORTS Value: 1359.0, Count: 2028
# PORTS Value: 1360.0, Count: 3940
# PORTS Value: 1361.0, Count: 5256
# PORTS Value: 1362.0, Count: 3598
# PORTS Value: 1363.0, Count: 3961
# PORTS Value: 1364.0, Count: 2618
# PORTS Value: 1365.0, Count: 4809
# PORTS Value: 1366.0, Count: 2171
# PORTS Value: 1367.0, Count: 3419
# PORTS Value: 1368.0, Count: 1877
# PORTS Value: 1369.0, Count: 1790
# PORTS Value: 1370.0, Count: 5278
# PORTS Value: 1371.0, Count: 1851
# PORTS Value: 1372.0, Count: 2062
# PORTS Value: 1373.0, Count: 1428
# PORTS Value: 1374.0, Count: 4628
# PORTS Value: 1375.0, Count: 4270
# PORTS Value: 1376.0, Count: 2385
# PORTS Value: 1377.0, Count: 1327
# PORTS Value: 1378.0, Count: 1109
# PORTS Value: 1379.0, Count: 956
# PORTS Value: 1380.0, Count: 2493
# PORTS Value: 1381.0, Count: 2060
# PORTS Value: 1382.0, Count: 3247
# PORTS Value: 1383.0, Count: 1977
# PORTS Value: 1384.0, Count: 1478
# PORTS Value: 1385.0, Count: 3781
# PORTS Value: 1386.0, Count: 2044
# PORTS Value: 1387.0, Count: 4069
# PORTS Value: 1388.0, Count: 4163
# PORTS Value: 1389.0, Count: 1808
# PORTS Value: 1390.0, Count: 961
# PORTS Value: 1391.0, Count: 1748
# PORTS Value: 1392.0, Count: 2228
# PORTS Value: 1393.0, Count: 2081
# PORTS Value: 1394.0, Count: 2679
# PORTS Value: 1395.0, Count: 1130
# PORTS Value: 1396.0, Count: 4823
# PORTS Value: 1397.0, Count: 3665
# PORTS Value: 1398.0, Count: 2392
# PORTS Value: 1399.0, Count: 2870
# PORTS Value: 1400.0, Count: 1182
# PORTS Value: 1401.0, Count: 3649
# PORTS Value: 1402.0, Count: 3014
# PORTS Value: 1403.0, Count: 4621
# PORTS Value: 1405.0, Count: 1183
# PORTS Value: 1406.0, Count: 1490
# PORTS Value: 1407.0, Count: 1705
# PORTS Value: 1408.0, Count: 3119
# PORTS Value: 1409.0, Count: 2144
# PORTS Value: 1410.0, Count: 2924
# PORTS Value: 1411.0, Count: 2098
# PORTS Value: 1412.0, Count: 1912
# PORTS Value: 1413.0, Count: 2453
# PORTS Value: 1414.0, Count: 966
# PORTS Value: 1415.0, Count: 2709
# PORTS Value: 1416.0, Count: 1400
# PORTS Value: 1417.0, Count: 1927
# PORTS Value: 1418.0, Count: 687
# PORTS Value: 1419.0, Count: 1829
# PORTS Value: 1420.0, Count: 597
# PORTS Value: 1421.0, Count: 1891
# PORTS Value: 1422.0, Count: 4224
# PORTS Value: 1423.0, Count: 902
# PORTS Value: 1424.0, Count: 2541
# PORTS Value: 1426.0, Count: 1880
# PORTS Value: 1427.0, Count: 2509
# PORTS Value: 1428.0, Count: 925
# PORTS Value: 1429.0, Count: 1114
# PORTS Value: 1430.0, Count: 841
# PORTS Value: 1431.0, Count: 961
# PORTS Value: 1432.0, Count: 1563
# PORTS Value: 1433.0, Count: 2215
# PORTS Value: 1434.0, Count: 403
# PORTS Value: 1435.0, Count: 1578
# PORTS Value: 1436.0, Count: 3378
# PORTS Value: 1437.0, Count: 974
# PORTS Value: 1438.0, Count: 2287
# PORTS Value: 1439.0, Count: 1144
# PORTS Value: 1440.0, Count: 961
# PORTS Value: 1441.0, Count: 2574
# PORTS Value: 1442.0, Count: 1341
# PORTS Value: 1444.0, Count: 223
# PORTS Value: 1445.0, Count: 918
# PORTS Value: 1446.0, Count: 1506
# PORTS Value: 1447.0, Count: 620
# PORTS Value: 1448.0, Count: 833
# PORTS Value: 1449.0, Count: 2731
# PORTS Value: 1450.0, Count: 961
# PORTS Value: 1452.0, Count: 296
# PORTS Value: 1453.0, Count: 1189
# PORTS Value: 1454.0, Count: 1147
# PORTS Value: 1457.0, Count: 279
# PORTS Value: 1459.0, Count: 1054
# PORTS Value: 1460.0, Count: 937
# PORTS Value: 1462.0, Count: 1235
# PORTS Value: 1463.0, Count: 213
# PORTS Value: 1464.0, Count: 936
# PORTS Value: 1467.0, Count: 252
# PORTS Value: 1468.0, Count: 225
# PORTS Value: 1469.0, Count: 716
# PORTS Value: 1471.0, Count: 107
# PORTS Value: 1472.0, Count: 633
# PORTS Value: 1473.0, Count: 620
# PORTS Value: 1475.0, Count: 189
# PORTS Value: 1476.0, Count: 374
# PORTS Value: 1479.0, Count: 99
# PORTS Value: 1480.0, Count: 878
# PORTS Value: 1481.0, Count: 48
# PORTS Value: 1483.0, Count: 81
# PORTS Value: 1484.0, Count: 666
# PORTS Value: 1486.0, Count: 198
# PORTS Value: 1487.0, Count: 93
# PORTS Value: 1491.0, Count: 1159
# PORTS Value: 1495.0, Count: 954
# PORTS Value: 1496.0, Count: 419
# PORTS Value: 1499.0, Count: 323
# PORTS Value: 1500.0, Count: 510
# PORTS Value: 1503.0, Count: 93
# PORTS Value: 1504.0, Count: 234
# PORTS Value: 1506.0, Count: 505
# PORTS Value: 1507.0, Count: 465
# PORTS Value: 1508.0, Count: 637
# PORTS Value: 1510.0, Count: 286
# PORTS Value: 1512.0, Count: 370
# PORTS Value: 1515.0, Count: 305
# PORTS Value: 1516.0, Count: 247
# PORTS Value: 1517.0, Count: 641
# PORTS Value: 1518.0, Count: 528
# PORTS Value: 1519.0, Count: 314
# PORTS Value: 1522.0, Count: 541
# PORTS Value: 1523.0, Count: 787
# PORTS Value: 1526.0, Count: 647
# PORTS Value: 1528.0, Count: 316
# PORTS Value: 1529.0, Count: 104
# PORTS Value: 1530.0, Count: 64
# PORTS Value: 1531.0, Count: 460
# PORTS Value: 1533.0, Count: 43
# PORTS Value: 1534.0, Count: 65
# PORTS Value: 1535.0, Count: 262
# PORTS Value: 1537.0, Count: 123
# PORTS Value: 1538.0, Count: 426
# PORTS Value: 1539.0, Count: 334
# PORTS Value: 1540.0, Count: 113
# PORTS Value: 1541.0, Count: 289
# PORTS Value: 1542.0, Count: 195
# PORTS Value: 1545.0, Count: 324
# PORTS Value: 1547.0, Count: 233
# PORTS Value: 1548.0, Count: 217
# PORTS Value: 1549.0, Count: 1280
# PORTS Value: 1551.0, Count: 704
# PORTS Value: 1552.0, Count: 125
# PORTS Value: 1553.0, Count: 1102
# PORTS Value: 1554.0, Count: 108
# PORTS Value: 1556.0, Count: 321
# PORTS Value: 1557.0, Count: 1054
# PORTS Value: 1558.0, Count: 291
# PORTS Value: 1560.0, Count: 640
# PORTS Value: 1561.0, Count: 2275
# PORTS Value: 1562.0, Count: 753
# PORTS Value: 1563.0, Count: 1209
# PORTS Value: 1564.0, Count: 1317
# PORTS Value: 1565.0, Count: 195
# PORTS Value: 1567.0, Count: 1252
# PORTS Value: 1568.0, Count: 1098
# PORTS Value: 1569.0, Count: 50
# PORTS Value: 1571.0, Count: 1612
# PORTS Value: 1572.0, Count: 2140
# PORTS Value: 1573.0, Count: 273
# PORTS Value: 1574.0, Count: 960
# PORTS Value: 1576.0, Count: 3002
# PORTS Value: 1577.0, Count: 102
# PORTS Value: 1578.0, Count: 232
# PORTS Value: 1580.0, Count: 2122
# PORTS Value: 1583.0, Count: 1612
# PORTS Value: 1584.0, Count: 2029
# PORTS Value: 1586.0, Count: 961
# PORTS Value: 1587.0, Count: 961
# PORTS Value: 1588.0, Count: 53
# PORTS Value: 1589.0, Count: 961
# PORTS Value: 1590.0, Count: 702
# PORTS Value: 1591.0, Count: 916
# PORTS Value: 1592.0, Count: 940
# PORTS Value: 1594.0, Count: 651
# PORTS Value: 1595.0, Count: 2786
# PORTS Value: 1597.0, Count: 960
# PORTS Value: 1599.0, Count: 961
# PORTS Value: 1601.0, Count: 961
# PORTS Value: 1603.0, Count: 1899
# PORTS Value: 1604.0, Count: 713
# PORTS Value: 1606.0, Count: 653
# PORTS Value: 1607.0, Count: 1822
# PORTS Value: 1608.0, Count: 930
# PORTS Value: 1609.0, Count: 960
# PORTS Value: 1610.0, Count: 961
# PORTS Value: 1612.0, Count: 954
# PORTS Value: 1613.0, Count: 961
# PORTS Value: 1614.0, Count: 948
# PORTS Value: 1618.0, Count: 682
# PORTS Value: 1619.0, Count: 1677
# PORTS Value: 1620.0, Count: 961
# PORTS Value: 1621.0, Count: 1891
# PORTS Value: 1623.0, Count: 961
# PORTS Value: 1624.0, Count: 956
# PORTS Value: 1625.0, Count: 959
# PORTS Value: 1626.0, Count: 961
# PORTS Value: 1629.0, Count: 1635
# PORTS Value: 1630.0, Count: 1698
# PORTS Value: 1632.0, Count: 928
# PORTS Value: 1633.0, Count: 1918
# PORTS Value: 1636.0, Count: 961
# PORTS Value: 1637.0, Count: 961
# PORTS Value: 1638.0, Count: 772
# PORTS Value: 1640.0, Count: 961
# PORTS Value: 1641.0, Count: 2335
# PORTS Value: 1642.0, Count: 1704
# PORTS Value: 1644.0, Count: 929
# PORTS Value: 1645.0, Count: 2504
# PORTS Value: 1646.0, Count: 961
# PORTS Value: 1649.0, Count: 1922
# PORTS Value: 1650.0, Count: 1448
# PORTS Value: 1653.0, Count: 961
# PORTS Value: 1654.0, Count: 868
# PORTS Value: 1655.0, Count: 1395
# PORTS Value: 1657.0, Count: 1707
# PORTS Value: 1661.0, Count: 622
# PORTS Value: 1662.0, Count: 410
# PORTS Value: 1663.0, Count: 2473
# PORTS Value: 1666.0, Count: 866
# PORTS Value: 1668.0, Count: 2112
# PORTS Value: 1671.0, Count: 533
# PORTS Value: 1674.0, Count: 961
# PORTS Value: 1676.0, Count: 961
# PORTS Value: 1678.0, Count: 653
# PORTS Value: 1680.0, Count: 961
# PORTS Value: 1681.0, Count: 961
# PORTS Value: 1682.0, Count: 118
# PORTS Value: 1687.0, Count: 961
# PORTS Value: 1688.0, Count: 773
# PORTS Value: 1689.0, Count: 1906
# PORTS Value: 1692.0, Count: 961
# PORTS Value: 1694.0, Count: 866
# PORTS Value: 1695.0, Count: 14
# PORTS Value: 1696.0, Count: 961
# PORTS Value: 1698.0, Count: 961
# PORTS Value: 1703.0, Count: 890
# PORTS Value: 1704.0, Count: 930
# PORTS Value: 1706.0, Count: 2883
# PORTS Value: 1712.0, Count: 1133
# PORTS Value: 1713.0, Count: 17
# PORTS Value: 1714.0, Count: 930
# PORTS Value: 1715.0, Count: 879
# PORTS Value: 1716.0, Count: 296
# PORTS Value: 1718.0, Count: 930
# PORTS Value: 1719.0, Count: 238
# PORTS Value: 1720.0, Count: 961
# PORTS Value: 1722.0, Count: 961
# PORTS Value: 1725.0, Count: 961
# PORTS Value: 1726.0, Count: 385
# PORTS Value: 1727.0, Count: 599
# PORTS Value: 1728.0, Count: 558
# PORTS Value: 1730.0, Count: 3352
# PORTS Value: 1731.0, Count: 961
# PORTS Value: 1738.0, Count: 1922
# PORTS Value: 1741.0, Count: 961
# PORTS Value: 1742.0, Count: 700
# PORTS Value: 1744.0, Count: 961
# PORTS Value: 1745.0, Count: 837
# -----------------

# %% [markdown]
# # Random Forest model using BalancedRandomForestClassifier:

# %%
brfc = BalancedRandomForestClassifier(random_state=42, class_weight= 'balanced', sampling_strategy='not majority')

# Define a basic parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],   # number of trees in the forest
    'max_depth': [None, 5, 10, 20]    # maximum depth of the tree
}

# Set scoring metrics
scoring = {
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1',
    'roc_auc': 'roc_auc'
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    estimator = brfc,
    param_grid=param_grid,
    scoring=scoring,
    refit='f1',  # because we are interested in maximizing f1_score
    cv=5,
    n_jobs=19,
    verbose=0
)

# %% [markdown]
# # Info on CV, fit, predict, predict_proba
#
# Cross-validation is a technique used to evaluate the performance of a machine learning model by training and testing it on different subsets of the dataset. It helps assess how well the model generalizes to new, unseen data and helps mitigate the risk of overfitting.
#
# Here's how the 5-fold cross-validation works:
#
# 1. The entire dataset (X_cleaned and y_cleaned) is divided into 5 equally sized (or nearly equal) folds.
# 2. The model is trained and tested 5 times. In each iteration, one of the folds is used as the test set, and the remaining 4 folds are used to train the model.
# 3. For each iteration, the model's performance is evaluated using a chosen evaluation metric (in this case, accuracy, which is the default scoring method for cross_val_score).
# 4. Once all 5 iterations are completed, the performance scores are averaged to give a single cross-validation score.
#
# By using cross-validation, you get a more reliable estimate of the model's performance because it's tested on different portions of the dataset. This helps to reduce the risk of overfitting and gives you a better understanding of how well your model generalizes to unseen data.
#
# Cross-validation is performed before  `clf.fit` to assess the performance of the model on the data without using the same data for both training and validation. It helps to understand how well the model is likely to generalize to new, unseen data before committing to training the final model.
#
#  If the cross-validation scores are satisfactory, you can proceed to train the final model using the entire dataset with clf.fit.
#
#  `clf.fit` is the method used to train the machine learning model on the provided dataset. In this case, it's training the Random Forest Classifier (denoted as `clf`) on the training dataset (`X_train` and `y_train`). The purpose of `clf.fit` is to learn the relationship between the input features (`X_train`) and the target variable (`y_train`) so that the model can make predictions on new, unseen data.
#
# `clf.predict` is the method used to make predictions using the trained model. Once the model is trained with `clf.fit`, it can then be used to predict the target variable for new input features.
#
# The model is predicting probabilities. The RandomForestClassifier, by default, outputs probabilities of class membership. It provides the probability of each pixel belonging to the deforested or non-deforested class. However, when you use `clf.predict()`, it returns the class with the highest probability, which is a **binary result (deforested or non-deforested).**
#
#  The **`clf.predict_proba()`** function obtains probabilities instead of the binary result returning probabilities of each class. ` y_proba = clf.predict_proba(X_cleaned)[:, 1] `extracts the probabilities of deforestation events (class 1) for all pixels.

# %%
# Fit GridSearch to the BalancedRandomForestClassifier data
grid_search.fit(X_train, y_train)
#Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %% [markdown]
# # Examine Fit Results
#
# grid_search.best_params_ contains the hyperparameter combination that resulted in the highest average cross-validation score across the different folds during the grid search. This is useful information as it tells you which hyperparameters worked best for your model and data.
#
# grid_search.best_score_ is the highest mean cross-validation score achieved by the best hyperparameter combination found in the grid search. It gives you an idea of the model's performance with the optimal hyperparameters during the cross-validation process.
#
# Best estimator: This provides the best estimator found by grid search. This is already fitted to the data and can be used for making predictions or further analysis.
#
# CV Results: This provides a dictionary with various details about the grid search, like scores for each combination of parameters, time taken for fitting and scoring, etc. Note: cv_results_ is a dictionary and can be quite verbose, you may want to convert it into a DataFrame for easier viewing.
#
# Scorer: This provides the scoring function used by grid search.
#
# Refit Time: This gives the time taken to refit the best estimator with the entire dataset.

# %%
# Print all available attributes and methods for the random_search object
all_attributes_methods = dir(grid_search)

# Filter out attributes and methods inherited from BaseSearchCV
specific_attributes_methods = [
    attribute for attribute in all_attributes_methods
    if attribute not in dir(GridSearchCV)
]

print("Attributes and methods specific to GridSearchCV:")
for attr in specific_attributes_methods:
    print(attr)
# Out:
# Attributes and methods specific to GridSearchCV:
# best_estimator_
# best_index_
# best_params_
# best_score_
# cv
# cv_results_
# error_score
# estimator
# multimetric_
# n_jobs
# n_splits_
# param_grid
# pre_dispatch
# refit
# refit_time_
# return_train_score
# scorer_
# scoring
# verbose

# %%
def is_fitted(estimator):
    try:
        getattr(estimator, "estimators_")
        return True
    except AttributeError:
        return False

print(is_fitted(brfc))
# Out:
# False

# %%
grid_search.score
# Out:
# <bound method BaseSearchCV.score of GridSearchCV(cv=5,
#              estimator=BalancedRandomForestClassifier(class_weight='balanced',
#                                                       random_state=42,
#                                                       sampling_strategy='not '
#                                                                         'majority'),
#              n_jobs=19,
#              param_grid={'max_depth': [None, 5, 10, 20],
#                          'n_estimators': [50, 100, 200]},
#              refit='f1',
#              scoring={'f1': 'f1', 'precision': 'precision', 'recall': 'recall',
#                       'roc_auc': 'roc_auc'})>

# %%
# Get the best parameters and the corresponding score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

best_estimator = grid_search.best_estimator_

cv_results = grid_search.cv_results_

cv_results_df = pd.DataFrame(grid_search.cv_results_)

scorer = grid_search.scorer_

refit_time = grid_search.refit_time_
# Out:
# Best parameters: {'max_depth': None, 'n_estimators': 50}
# Best cross-validation score: 0.4845839150573231

# %% [markdown]
# After fitting the GridSearchCV, you can evaluate the performance of the best model on the test data (X_test and y_test) using the best_estimator_ attribute of the grid_search object:

# %%
print("Best parameters:", best_params)
print("Best cross-validation score:", best_score)
print("Best estimator:", best_estimator)
print("CV Results:",cv_results_df)
print("Scorer function:", scorer)
print("Refit time (seconds):", refit_time)
# Out:
# Best parameters: {'max_depth': None, 'n_estimators': 50}
# Best cross-validation score: 0.4845839150573231
# Best estimator: BalancedRandomForestClassifier(class_weight='balanced', n_estimators=50,
#                                random_state=42,
#                                sampling_strategy='not majority')
# CV Results:     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      535.629575      2.330320        31.496318        0.155117
# 1     1069.753634      6.405724        56.478282        0.184474
# 2     2165.919110     19.817767       154.048608        5.364894
# 3      535.728546      3.833532        31.584356        0.071081
# 4     1062.729164      4.347988        95.832514        1.050506
# 5     2280.197555     96.314744       106.971950        0.609603
# 6      563.289992     26.147850        33.580086        2.533693
# 7     1133.890707     33.708493       117.828511       21.865802
# 8     2208.049586     78.751899       110.331541       12.376744
# 9      564.648655     29.856377        36.018730        7.309556
# 10    1064.418717     12.824489        62.287242       11.113011
# 11    2095.983412     14.954348       102.118531        0.664861
#
#    param_max_depth param_n_estimators  \
# 0             None                 50
# 1             None                100
# 2             None                200
# 3                5                 50
# 4                5                100
# 5                5                200
# 6               10                 50
# 7               10                100
# 8               10                200
# 9               20                 50
# 10              20                100
# 11              20                200
#
#                                       params  split0_test_precision  \
# 0    {'max_depth': None, 'n_estimators': 50}               0.355341
# 1   {'max_depth': None, 'n_estimators': 100}               0.355341
# 2   {'max_depth': None, 'n_estimators': 200}               0.355341
# 3       {'max_depth': 5, 'n_estimators': 50}               0.355341
# 4      {'max_depth': 5, 'n_estimators': 100}               0.355341
# 5      {'max_depth': 5, 'n_estimators': 200}               0.355341
# 6      {'max_depth': 10, 'n_estimators': 50}               0.355341
# 7     {'max_depth': 10, 'n_estimators': 100}               0.355341
# 8     {'max_depth': 10, 'n_estimators': 200}               0.355341
# 9      {'max_depth': 20, 'n_estimators': 50}               0.355341
# 10    {'max_depth': 20, 'n_estimators': 100}               0.355341
# 11    {'max_depth': 20, 'n_estimators': 200}               0.355341
#
#     split1_test_precision  split2_test_precision  ...  std_test_f1  \
# 0                0.355647               0.355298  ...     0.000301
# 1                0.355647               0.355298  ...     0.000301
# 2                0.355647               0.355298  ...     0.000301
# 3                0.355647               0.355298  ...     0.000301
# 4                0.355647               0.355298  ...     0.000301
# 5                0.355647               0.355298  ...     0.000301
# 6                0.355647               0.355298  ...     0.000301
# 7                0.355647               0.355298  ...     0.000301
# 8                0.355647               0.355298  ...     0.000301
# 9                0.355647               0.355298  ...     0.000301
# 10               0.355647               0.355298  ...     0.000301
# 11               0.355647               0.355298  ...     0.000301
#
#     rank_test_f1  split0_test_roc_auc  split1_test_roc_auc  \
# 0              1             0.765407             0.765637
# 1              1             0.765407             0.765637
# 2              1             0.765407             0.765637
# 3              1             0.765407             0.765637
# 4              1             0.765407             0.765637
# 5              1             0.765407             0.765637
# 6              1             0.765407             0.765637
# 7              1             0.765407             0.765637
# 8              1             0.765407             0.765637
# 9              1             0.765407             0.765637
# 10             1             0.765407             0.765637
# 11             1             0.765407             0.765637
#
#     split2_test_roc_auc  split3_test_roc_auc  split4_test_roc_auc  \
# 0              0.765439             0.765824             0.765295
# 1              0.765439             0.765824             0.765295
# 2              0.765439             0.765824             0.765295
# 3              0.765439             0.765824             0.765295
# 4              0.765439             0.765824             0.765295
# 5              0.765439             0.765824             0.765295
# 6              0.765439             0.765824             0.765295
# 7              0.765439             0.765824             0.765295
# 8              0.765439             0.765824             0.765295
# 9              0.765439             0.765824             0.765295
# 10             0.765439             0.765824             0.765295
# 11             0.765439             0.765824             0.765295
#
#     mean_test_roc_auc  std_test_roc_auc  rank_test_roc_auc
# 0             0.76552          0.000188                  1
# 1             0.76552          0.000188                  1
# 2             0.76552          0.000188                  1
# 3             0.76552          0.000188                  1
# 4             0.76552          0.000188                  1
# 5             0.76552          0.000188                  1
# 6             0.76552          0.000188                  1
# 7             0.76552          0.000188                  1
# 8             0.76552          0.000188                  1
# 9             0.76552          0.000188                  1
# 10            0.76552          0.000188                  1
# 11            0.76552          0.000188                  1
#
# [12 rows x 39 columns]
# Scorer function: {'precision': make_scorer(precision_score, average=binary), 'recall': make_scorer(recall_score, average=binary), 'f1': make_scorer(f1_score, average=binary), 'roc_auc': make_scorer(roc_auc_score, needs_threshold=True)}
# Refit time (seconds): 602.0482501983643

# %% [markdown]
# # Evaluate the model performance using your preferred metrics
# e.g., confusion matrix, classification report, accuracy, F1-score, etc.

# %%
best_model = grid_search.best_estimator_

# %%
# Predictions for test data
y_pred = best_model.predict(X_test)

# %% [markdown]
# Evaluate the performance of your model by comparing the predicted labels (y_pred) with the true labels (y_test). You can use various metrics such as confusion matrix, classification report, accuracy, F1-score, etc.:

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate F1-score (use 'weighted' or 'macro' depending on your problem)
f1 = f1_score(y_test, y_pred, average='weighted')
print("F1-score:", f1)

# Print classification report
report = classification_report(y_test, y_pred)
print("Classification report:\n", report)
# Out:
# Accuracy: 0.6869900388432683
# F1-score: 0.7190388232149647
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.67      0.78   9184478
#            1       0.36      0.76      0.48   2202051
#
#     accuracy                           0.69  11386529
#    macro avg       0.64      0.72      0.63  11386529
# weighted avg       0.81      0.69      0.72  11386529

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
# Predictions for train data
y_pred_train = best_model.predict(X_train)

# %%
# Confusion matrix and classification report for train data
train_cm = confusion_matrix(y_train, y_pred_train)
train_cr = classification_report(y_train, y_pred_train)
print("Training confusion matrix:")
print(train_cm)
print("Training classification report:")
print(train_cr)
# Out:
# Training confusion matrix:
# [[14341028  7089417]
#  [ 1228126  3909994]]
# Training classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.78  21430445
#            1       0.36      0.76      0.48   5138120
#
#     accuracy                           0.69  26568565
#    macro avg       0.64      0.72      0.63  26568565
# weighted avg       0.81      0.69      0.72  26568565

# %%
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_estimator(
        brfc,
        X_test,
        y_test,
        cmap=plt.cm.Blues)

title = disp.ax_.set_title("Confusion matrix")

print(title)
print(disp.confusion_matrix)

plt.show()

# %%
# Calculate feature importances and the standard deviation for those importances
importances = best_model.feature_importances_
std = np.std([tree.feature_importances_ for tree in best_model.estimators_], axis=0)


 # list of feature names corresponding to the input bands of your raster stack
feature_names = ['TreeCover2010','LUP']
# Create a sorted list of tuples containing feature names and their importances:
sorted_features = sorted(zip(feature_names, importances, std), key=lambda x: x[1], reverse=True)

# Create a bar chart
fig, ax = plt.subplots()

# Set the feature names as x-axis labels
ax.set_xticklabels([item[0] for item in sorted_features], rotation=45, ha='right')
ax.set_xticks(range(len(sorted_features)))

# Set the y-axis labels as importances
ax.bar(range(len(sorted_features)), [item[1] for item in sorted_features], yerr=[item[2] for item in sorted_features])

# Set the title and labels for the chart
ax.set_title('Feature Importances')
ax.set_xlabel('Features')
ax.set_ylabel('Importance')

# Display the chart
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3535282/2283730908.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([item[0] for item in sorted_features], rotation=45, ha='right')

# %% [markdown]
# # Probabilities for deforestation

# %%
y_proba_curve = best_model.predict_proba(X_test)[:, 1]

# %%
print("Shape of y_proba_curve:", y_proba_curve.shape)
# Out:
# Shape of y_proba_curve: (11386529,)

# %%
# Precision-Recall curve
precision, recall, _ = precision_recall_curve(y_test, y_proba_curve)
plt.plot(recall, precision, marker='.', label='Random Forest')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.show()

print(f"Area under Precision-Recall curve: {auc(recall, precision)}")

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_proba_curve)
plt.plot(fpr, tpr, marker='.', label='Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

print(f"Area under ROC curve: {auc(fpr, tpr)}")
# Out:
# Area under Precision-Recall curve: 0.5569854569566302
# Area under ROC curve: 0.7656242397606493

# %%
# Predict probabilities for deforestation events
y_proba = best_model.predict_proba(X_cleaned)[:, 1]

# %%
# Predicts the 
# Create a probability raster by filling in the valid pixel values
prob_raster = np.full(y.shape, no_data_value, dtype=np.float32)
prob_raster[valid_rows] = y_proba
prob_raster = prob_raster.reshape(feature_data_arrays[0].shape)

# %%
print(y_proba.shape)
# Out:
# (37955094,)

# %%
# Save the probability raster as a GeoTIFF file
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output_file = os.path.join(output_folder, "deforestation_prob_balanced.tiff")

with rasterio.open(y_file) as src:
    profile = src.profile
    profile.update(dtype=rasterio.float32, count=1)

prob_raster_reshaped = prob_raster.reshape((1, prob_raster.shape[0], prob_raster.shape[1]))

with rasterio.open(output_file, 'w', **profile) as dst:
    dst.write_band(1, prob_raster_reshaped[0])

# %% [markdown]
# # Tuning Strategies

# %%
# Randomized Search
# Set the range of values for each hyperparameter
'''param_dist = {
    "n_estimators": sp_randint(100, 300),
    'criterion': ['gini',],
    'max_features': ['sqrt', None],
    "max_depth": sp_randint(1, 20),
    "min_samples_split": sp_randint(2, 11),
    "min_samples_leaf": sp_randint(1, 11),
    "bootstrap": [True],
    'class_weight': ['balanced']
}

# Instantiate the RandomForestClassifier
clf = RandomForestClassifier(random_state=0)

# Set up the RandomizedSearchCV
random_search = RandomizedSearchCV(
    clf, param_distributions=param_dist, n_iter=20, cv=5, random_state=0, n_jobs=19
)'''
# Out:
# 'param_dist = {\n    "n_estimators": sp_randint(100, 300),\n    \'criterion\': [\'gini\',],\n    \'max_features\': [\'sqrt\', None],\n    "max_depth": sp_randint(1, 20),\n    "min_samples_split": sp_randint(2, 11),\n    "min_samples_leaf": sp_randint(1, 11),\n    "bootstrap": [True],\n    \'class_weight\': [\'balanced\']\n}\n\n# Instantiate the RandomForestClassifier\nclf = RandomForestClassifier(random_state=0)\n\n# Set up the RandomizedSearchCV\nrandom_search = RandomizedSearchCV(\n    clf, param_distributions=param_dist, n_iter=20, cv=5, random_state=0, n_jobs=19\n)'
